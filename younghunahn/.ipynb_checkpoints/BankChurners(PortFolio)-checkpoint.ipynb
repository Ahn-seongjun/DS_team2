# %% [markdown]
# ### 머신러닝 기반 카드 이탈고객 예측
#      1. 개요
#      2. 데이터 수집
#      3. 데이터 확인 및 시각화
#      4. 데이터 전처리 및 피쳐 엔지니어링
#          (1) 타겟 데이터 전처리
#          (2) 피처 데이터 전처리
#          (3) 피처 데이터 변수 선택
#          (4) 피처 엔지니어링
#      5. 모델링
#          (1) 지도학습
#          (2) 군집화
#      6. 테스팅

# %% [markdown]
# ### 1. 개요
#
# - 카드 회사들은 고객 유치를 위해 많은 프로모션을 진행
# - 새로운 고객을 유치하는 것보다 기존 고객을 유지하는 것이 경제적 효과큼
# - 기존 고객의 이탈 여부를 사전에 예측 가능한 모델 구축

# %% [markdown]
# ### 2. 데이터 수집
#
# - 데이터 출처 (링크 [kaggle](https://www.kaggle.com/sakshigoyal7/credit-card-customers))
# - 은행의 고객 중에서 신용카드 고객 이탈자에 대한 자료
# - 이탈 고객의 16.07%만 자료를 가지고 있어서 한계가 있는 데이터임
# - 연령, 급여, 결혼 여부, 신용카드 한도, 신용카드 등급 등 여러 정보를 가지고 이탈 고객 분석

# %% [markdown]
# ### 3. 데이터 확인 및 시각화

# %% [markdown]
# **모듈 임포트**

# %%
import pandas as pd # 데이터 핸들링 
import numpy as np 
import matplotlib.pyplot as plt # 데이터 시각화 
# %matplotlib inline
import seaborn as sns # 데이터 시각화(고급분석)

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')
# Out:
# Unknown system...  sorry~~~

# %% [markdown]
# **데이터 불러오기**
# - 데이터명 : **df**
# - 경로 :  **"./data/BankChurners.csv"**로 통일하였다.

# %%
df = pd.read_csv("/Users/ds/project2/HuijinKim/data/BankChurners.csv")
## 불필요한 열 2개 제거
df = df.iloc[:,:-2]

# %%
df.keys()
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %% [markdown]
# ####  데이터 정보
# - ~'CLIENTNUM' : 고객 식별 번호~
# - 'Attrition_Flag' : 신용 카드 이탈 여부 **``Target 값``**
#     - Existing Customer : 잔류
#     - Attrited Customer : 이탈
# - 'Customer_Age' : 고객 나이
# - 'Gender' : 성별
# - 'Dependent_count' : 부양 가족 수
# - 'Education_Level' : 학력 수준
# - 'Marital_Status' : 결혼 여부
# - 'Income_Category' : 연 소득 구간
# - 'Card_Category' : 카드 등급
# - 'Months_on_book' : 카드 할부 기간
# - 'Total_Relationship_Count' : 가입 상품 수
# - 'Months_Inactive_12_mon' : 1년 동안 카드 결재 내역이 없는 비활성 기간(개월)
# - 'Contacts_Count_12_mon' : 연락 빈도
# - 'Credit_Limit' : 신용 한도
# - 'Total_Revolving_Bal' : 할부 잔액
# - ~'Avg_Open_To_Buy' : 평균 실 사용 가능 금액 :  'Credit_Limit' -  'Total_Revolving_Bal'~
# - ~'Total_Amt_Chng_Q4_Q1'~ : 결제 대금 기준 1분기 대비 4분기 (비율)
# - ~'Total_Trans_Amt'~ : 실제 사용 총액
# - 'Total_Trans_Ct' : 실제 사용 횟수
# - 'Total_Ct_Chng_Q4_Q1' : 1분기 대비 4분기 결제 대금 횟수 비율
# - ~'Avg_Utilization_Ratio' : 'Total_Revolving_Bal'/ 'Credit_Limit' (할부 비율)~

# %% [markdown]
# | 변수명                   | 변수형태 | 구분     |
# | :------------------------: | :--------: | :--------: |
# | CLIENTNUM                | INT      | 피처변수 |
# | Customer_Age             | INT      | 피처변수 |
# | Gender                   | Object   | 피처변수 |
# | Dependent_count          | INT      | 피처변수 |
# | Education_Level          | Object   | 피처변수 |
# | Marital_Status           | Object   | 피처변수 |
# | Income_Category          | Object   | 피처변수 |
# | Card_Category            | Object   | 피처변수 |
# | Months_on_book           | INT      | 피처변수 |
# | Total_Relationship_Count | INT      | 피처변수 |
# | Months_Inactive_12_mon   | INT      | 피처변수 |
# | Contacts_Count_12_mon    | INT      | 피처변수 |
# | Credit_Limit             | INT      | 피처변수 |
# | Total_Revolving_Bal      | INT      | 피처변수 |
# | Avg_Open_To_Buy          | INT      | 피처변수 |
# | Total_Amt_Chng_Q4_Q1     | INT      | 피처변수 |
# | Total_Trans_Amt          | INT      | 피처변수 |
# | Total_Trans_Ct           | INT      | 피처변수 |
# | Total_Ct_Chng_Q4_Q1      | INT      | 피처변수 |
# | Avg_Utilization_Ratio    | INT      | 피처변수 |

# %% [markdown]
# **데이터 확인**

# %%
## 데이터 유형 및 결측치 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
#  13  Credit_Limit              10127 non-null  float64
#  14  Total_Revolving_Bal       10127 non-null  int64
#  15  Avg_Open_To_Buy           10127 non-null  float64
#  16  Total_Amt_Chng_Q4_Q1      10127 non-null  float64
#  17  Total_Trans_Amt           10127 non-null  int64
#  18  Total_Trans_Ct            10127 non-null  int64
#  19  Total_Ct_Chng_Q4_Q1       10127 non-null  float64
#  20  Avg_Utilization_Ratio     10127 non-null  float64
# dtypes: float64(5), int64(10), object(6)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000

# %% [markdown]
# **시각화 ( sns.pairplot(df) )**
# - 사용할 데이터의 상관관계를 파악하기 위해 시각화
# - 모든 칼럼에 대한 시각화

# %%
### 실행시간으로 인한 주석 처리
# sns.pairplot(df)

# %% [markdown]
# **결측치 확인**
# - isnull().sum() 코드에서는 결측치가 존재하지 않는 것을 확인
# - 각각의 피처를 분석해서 결측치 존재 여부 확인 필요

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %% [markdown]
# ### 4. 데이터 전처리 및 피쳐 엔지니어링

# %% [markdown]
# #### 4 (1) 타겟 데이터 전처리

# %% [markdown]
# - 관측 대상 : **``"Attrited Customer"``** 1로 설정 (카드 탈퇴)
# - 비관측 대상 : **``"Existing Cumstomer"``** 0으로 설정 (카드 유지)

# %%
df["Attrition_Flag"].value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
# 타겟 데이터의 분포를 바 플롯을 이용하여 시각화
df["Attrition_Flag"].value_counts().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
# 타겟 데이터의 분포를 파이 플롯을 이용하여 시각화
labels = ['Existing Customer', 'Attrited Customer']
size = df['Attrition_Flag'].value_counts()
colors = ['#5bc959','#d5b1aa' ]
explode = [0, 0.1]

plt.style.use('seaborn-deep')
plt.rcParams['figure.figsize'] = (6, 6)
plt.pie(size, labels =labels, colors = colors, explode = explode, autopct = "%.1f%%", shadow = True, textprops = {'fontsize':15})
plt.axis('off')
plt.title('Attrition (비율)', fontsize = 20)
plt.legend()
plt.show()
# Out:
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50984 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50984 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# **레이블 인코딩**
# - "Existing Cumstomer" : 0 (카드 잔존)
# - "Attrited Customer" : 1 (카드 탈퇴)

# %% [markdown]
# **주의하여 관측해아할 것이**
# ``"탈퇴"여부이기 때문에 탈퇴를 1, 잔존을 0으로 하여 인코딩``

# %%
df["Attrition_Flag"].replace({"Existing Customer":0,
                            "Attrited Customer":1,
                            },inplace=True)

# %%
df["Attrition_Flag"].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df["Attrition_Flag"].value_counts() # 전처리 확인
# Out:
# 0    8500
# 1    1627
# Name: Attrition_Flag, dtype: int64

# %% [markdown]
# **Existing Cumstomer(잔존)과 Attrited Customer(이탈)의 비율에 차이가 있다. 수치를 비교해보도록 한다.**

# %%
Existing = df[df["Attrition_Flag"]==0]
Attrited = df[df["Attrition_Flag"]==1]

Existing_ratio = len(Existing)/len(Existing+Attrited)
Attrited_ratio = len(Attrited)/len(Existing+Attrited)

print("카드를 유지한 고객은 {:.2f} 이고, 탈퇴 고객은 {:.2f}이므로, 카드를 유지한 고객이 {:.0f}배 많다".format(Existing_ratio,Attrited_ratio,Existing_ratio/Attrited_ratio))
# Out:
# 카드를 유지한 고객은 0.84 이고, 탈퇴 고객은 0.16이므로, 카드를 유지한 고객이 5배 많다

# %% [markdown]
# **업샘플링(오버샘플링)이나 다운샘플링(언더샘플링)이 필요한지 확인해 보아야한다.(업샘플링을 해야한다)**

# %% [markdown]
# **업샘플링은 전처리 과정이 아니라, 모델을 돌리면서 성능을 높이기 위한 작업과정이다 >> **업샘플링 하기 전에 모델링을 한번 하고 >> 모델의 성능을 높이기 위한 방법으로 업샘플링을진행한다****

# %% [markdown]
# #### 4 (2) 피처 데이터 전처리

# %% [markdown]
# **분류 분석에서의 피처(독립)변수들은 피처들간의 상관성이 높지 않은 이상은 웬만하면 버리지 않고(삭제하지 않고) 쓰는 방향으로 작업을 진행한다**

# %% [markdown]
# **피처변수들은 Labels(명목척도) , Orders(서열척도), Numerics(수치형) 변수로 구분하여 전처리를 진행하였다.**

# %%
Labels = ['Gender','Marital_Status'] # 명목 척도
Orders = ['Education_Level','Income_Category','Card_Category'] # 서열 척도 (등간 척도)
Numerics = ['Customer_Age','Dependent_count','Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'] # 수치형 변수

# %% [markdown]
# **Customer_Age(나이)**

# %%
sns.distplot(df["Customer_Age"])
# Out:
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Customer_Age', ylabel='Density'>

# %% [markdown]
# **Customer_Age (나이) 칼럼은 거의 완벽한 정규분포를 따른다는 것을 알 수 있다.**

# %% [markdown]
# **이상치 확인(시각화)**

# %%
df[["Customer_Age"]].boxplot()
sns.boxplot(df["Customer_Age"])
# Out:
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Customer_Age'>

# %% [markdown]
# **이상치 확인 (수치 확인)**
#     여기서 박스플롯에서 범위 밖으로 넘어가는 2개의 plot이 보이는데, 이 값이 이 범위를 벗어난다고 하더라도, 이 수치가 데이터 분석에 큰 영향을 끼치지 않으면 ( 말이 안되는 값이거나 범위에서 너무 벗어난 값 -예를 들면 우리나라 연봉을 조사하는데 이재용 삼성 부회장의 연봉은 제외를 해야 한다. ) 그 값은 이상치로 취급하지 않는다.

# %%
df["Customer_Age"].max()
# Out:
# 73

# %% [markdown]
# **나이 칼럼에서 가장 큰 수치는 73인데 이 수치는 충분히 가능한 값이다.만약 이 값이 200이다 라고 한다면 이 이상치는 삭제나 대체가 필요하지만, 73세는 나이로서 충분히 가능한 수치이므로 전처리 하지않는다.(이상치 취급하지 않음)**

# %%
# 이상치 확인 (참고 사항)
q1 = np.quantile(df["Customer_Age"],0.25)  
q3 = np.quantile(df["Customer_Age"],0.75) 
iqr = q3-q1
q3+iqr*1.5
q1-iqr*1.5

cond1 = q3+iqr*1.5<df["Customer_Age"]
cond2 = df["Customer_Age"]<q1-iqr*1.5

outlier_index = df[cond1 | cond2].index

# %% [markdown]
# **Gender(성별)**

# %%
# 성별의 분포를 bar 그래프를 이용하여 시각화
df['Gender'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# 성별 이탈고객 수
gend_df = pd.DataFrame(df.loc[:,['Gender','Attrition_Flag']].value_counts())
gend_df
# Out:
#                           0
# Gender Attrition_Flag
# F      0               4428
# M      0               4072
# F      1                930
# M      1                697

# %%
# 성별 평균 나이
df.groupby('Gender')['Customer_Age'].agg(**{'Customer_Age':'mean'}).reset_index()
# Out:
#   Gender  Customer_Age
# 0      F     46.456887
# 1      M     46.178863

# %%
# 성별 나이 분포
df[['Gender','Customer_Age']].value_counts()
# Out:
# Gender  Customer_Age
# F       44              277
#         45              272
#         49              263
#         47              258
#         48              249
#                        ...
#         66                2
# M       67                2
#         68                2
#         70                1
#         73                1
# Length: 86, dtype: int64

# %%
# 성별 라벨링 F : 0, M : 1
df["Gender"].replace({"F":1, "M":0},inplace=True)

# %%
df["Gender"].value_counts()
# Female 아니면 Male로 이진분류가 잘 되어있다.
# Label Encoding
# Out:
# 1    5358
# 0    4769
# Name: Gender, dtype: int64

# %%
# 다른 코드 
# from sklearn.preprocessing import LabelEncoder

# le = LabelEncoder()
# le.fit(df["Gender"])
# df["Gender"] = le.transform(df["Gender"])

# %%
df["Gender"] # 라벨인코딩 된 것을 확인 할 수 있다.
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 10122    0
# 10123    0
# 10124    1
# 10125    0
# 10126    1
# Name: Gender, Length: 10127, dtype: int64

# %%
# 부양 가족 수 값
df['Dependent_count'].value_counts().index
# Out:
# Int64Index([3, 2, 1, 4, 0, 5], dtype='int64')

# %%
# 부양 가족 수 분포
plt.title('Dependent_count')
sns.countplot(df["Dependent_count"])
# Out:
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Dependent_count'}, xlabel='Dependent_count', ylabel='count'>

# %%
bins = list(range(20,81,10))
bins
# Out:
# [20, 30, 40, 50, 60, 70, 80]

# %%
labels = [str(i) + '대' for i in bins]
labels
# Out:
# ['20대', '30대', '40대', '50대', '60대', '70대', '80대']

# %%
# 나이대 라벨 추가
df["age_bin"] = pd.cut(df["Customer_Age"], bins = bins, right = False, labels=labels[:-1])
df.head()
# Out:
#    CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383               0            45       0                3
# 1  818770008               0            49       1                5
# 2  713982108               0            51       0                3
# 3  769911858               0            40       1                4
# 4  709106358               0            40       0                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Contacts_Count_12_mon  Credit_Limit  \
# 0              39  ...                      3       12691.0
# 1              44  ...                      2        8256.0
# 2              36  ...                      0        3418.0
# 3              34  ...                      1        3313.0
# 4              21  ...                      0        4716.0
#
#    Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0                  777          11914.0                 1.335
# 1                  864           7392.0                 1.541
# 2                    0           3418.0                 2.594
# 3                 2517            796.0                 1.405
# 4                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0             1144              42                1.625
# 1             1291              33                3.714
# 2             1887              20                2.333
# 3             1171              20                2.333
# 4              816              28                2.500
#
#    Avg_Utilization_Ratio  age_bin
# 0                  0.061      40대
# 1                  0.105      40대
# 2                  0.000      50대
# 3                  0.760      40대
# 4                  0.000      40대
#
# [5 rows x 22 columns]

# %%
# 연령대별 평균 부양가족 수
dependent = df.groupby('age_bin')['Dependent_count'].agg(**{'dependent':'mean'}).reset_index()
dependent
# Out:
#   age_bin  dependent
# 0     20대   0.430769
# 1     30대   2.002173
# 2     40대   2.970401
# 3     50대   2.055037
# 4     60대   0.530189
# 5     70대   0.000000

# %%
# 연령대별 평균 부양 가족 수
sns.barplot(x='age_bin',y='dependent',data=dependent)
# Out:
# <AxesSubplot:xlabel='age_bin', ylabel='dependent'>
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 성별 평균 부양가족 수
gender = df.groupby('Gender')['Dependent_count'].agg(**{'dependent':'mean'}).reset_index()
gender
# Out:
#    Gender  dependent
# 0       0   2.352485
# 1       1   2.340612

# %%
# 연령대별 이탈고객
age_churn = pd.DataFrame(df.loc[:,['age_bin','Attrition_Flag']].value_counts().sort_index(ascending=True))
age_churn
# Out:
#                            0
# age_bin Attrition_Flag
# 20대     0                178
#         1                 17
# 30대     0               1580
#         1                261
# 40대     0               3789
#         1                772
# 50대     0               2492
#         1                506
# 60대     0                459
#         1                 71
# 70대     0                  2

# %% [markdown]
# ### 4 (2) 범주형 피처 인코딩

# %% [markdown]
# **Card_Category(카드 등급)**

# %%
# Card_Category(카드 등급) 은 4개의 등급(Blue, Silver, Gold, Platinum)으로 나뉘어진 범주형 변수이다. 
# 라벨링 인코딩을 해주도록 한다.
df["Card_Category"].replace({"Blue":0,
                                 "Silver":1,
                                 "Gold":2,
                                 "Platinum":3,
                                 },inplace=True)

# %% [markdown]
# **타겟변수(탈퇴인지, 잔존인지)에 따른 분포를 바 그래프로 보여주는 함수**

# %%
def bar_chart(feature):
    stay = df[df['Attrition_Flag']==0][feature].value_counts()
    leave = df[df['Attrition_Flag']==1][feature].value_counts()
    temp = pd.DataFrame([stay,leave])
    temp.index = ['Existing Customer','Attrited Customer']
    temp.plot(kind='bar',stacked=True, figsize=(10,5))
    plt.xticks(rotation=0)

# %% [markdown]
# **Education_Level 수준에 따른 고객 이탈자**

# %%
bar_chart('Education_Level') 
## unknown 알수 없음
## uneducated 중졸이하
## high school 고졸
## colleage 학사
## graduate / post-graduate 석사
## Docotrate 박사

# %%
## Unknown 학력을 알수 없는 정도가 1263
## Uneducated 1250

df[df['Attrition_Flag']==0]['Education_Level'].value_counts()
# Out:
# Graduate         2641
# High School      1707
# Unknown          1263
# Uneducated       1250
# College           859
# Post-Graduate     424
# Doctorate         356
# Name: Education_Level, dtype: int64

# %%
df.groupby(['Education_Level','Income_Category']).count()
# Out:
#                                  CLIENTNUM  Attrition_Flag  Customer_Age  \
# Education_Level Income_Category
# College         $120K +                 70              70            70
#                 $40K - $60K            183             183           183
#                 $60K - $80K            132             132           132
#                 $80K - $120K           175             175           175
#                 Less than $40K         345             345           345
#                 Unknown                108             108           108
# Doctorate       $120K +                 37              37            37
#                 $40K - $60K             70              70            70
#                 $60K - $80K             59              59            59
#                 $80K - $120K            57              57            57
#                 Less than $40K         158             158           158
#                 Unknown                 70              70            70
# Graduate        $120K +                204             204           204
#                 $40K - $60K            553             553           553
#                 $60K - $80K            422             422           422
#                 $80K - $120K           478             478           478
#                 Less than $40K        1139            1139          1139
#                 Unknown                332             332           332
# High School     $120K +                147             147           147
#                 $40K - $60K            355             355           355
#                 $60K - $80K            307             307           307
#                 $80K - $120K           308             308           308
#                 Less than $40K         671             671           671
#                 Unknown                225             225           225
# Post-Graduate   $120K +                 30              30            30
#                 $40K - $60K            111             111           111
#                 $60K - $80K             77              77            77
#                 $80K - $120K            81              81            81
#                 Less than $40K         170             170           170
#                 Unknown                 47              47            47
# Uneducated      $120K +                119             119           119
#                 $40K - $60K            249             249           249
#                 $60K - $80K            195             195           195
#                 $80K - $120K           217             217           217
#                 Less than $40K         522             522           522
#                 Unknown                185             185           185
# Unknown         $120K +                120             120           120
#                 $40K - $60K            269             269           269
#                 $60K - $80K            210             210           210
#                 $80K - $120K           219             219           219
#                 Less than $40K         556             556           556
#                 Unknown                145             145           145
#
#                                  Gender  Dependent_count  Marital_Status  \
# Education_Level Income_Category
# College         $120K +              70               70              70
#                 $40K - $60K         183              183             183
#                 $60K - $80K         132              132             132
#                 $80K - $120K        175              175             175
#                 Less than $40K      345              345             345
#                 Unknown             108              108             108
# Doctorate       $120K +              37               37              37
#                 $40K - $60K          70               70              70
#                 $60K - $80K          59               59              59
#                 $80K - $120K         57               57              57
#                 Less than $40K      158              158             158
#                 Unknown              70               70              70
# Graduate        $120K +             204              204             204
#                 $40K - $60K         553              553             553
#                 $60K - $80K         422              422             422
#                 $80K - $120K        478              478             478
#                 Less than $40K     1139             1139            1139
#                 Unknown             332              332             332
# High School     $120K +             147              147             147
#                 $40K - $60K         355              355             355
#                 $60K - $80K         307              307             307
#                 $80K - $120K        308              308             308
#                 Less than $40K      671              671             671
#                 Unknown             225              225             225
# Post-Graduate   $120K +              30               30              30
#                 $40K - $60K         111              111             111
#                 $60K - $80K          77               77              77
#                 $80K - $120K         81               81              81
#                 Less than $40K      170              170             170
#                 Unknown              47               47              47
# Uneducated      $120K +             119              119             119
#                 $40K - $60K         249              249             249
#                 $60K - $80K         195              195             195
#                 $80K - $120K        217              217             217
#                 Less than $40K      522              522             522
#                 Unknown             185              185             185
# Unknown         $120K +             120              120             120
#                 $40K - $60K         269              269             269
#                 $60K - $80K         210              210             210
#                 $80K - $120K        219              219             219
#                 Less than $40K      556              556             556
#                 Unknown             145              145             145
#
#                                  Card_Category  Months_on_book  \
# Education_Level Income_Category
# College         $120K +                     70              70
#                 $40K - $60K                183             183
#                 $60K - $80K                132             132
#                 $80K - $120K               175             175
#                 Less than $40K             345             345
#                 Unknown                    108             108
# Doctorate       $120K +                     37              37
#                 $40K - $60K                 70              70
#                 $60K - $80K                 59              59
#                 $80K - $120K                57              57
#                 Less than $40K             158             158
#                 Unknown                     70              70
# Graduate        $120K +                    204             204
#                 $40K - $60K                553             553
#                 $60K - $80K                422             422
#                 $80K - $120K               478             478
#                 Less than $40K            1139            1139
#                 Unknown                    332             332
# High School     $120K +                    147             147
#                 $40K - $60K                355             355
#                 $60K - $80K                307             307
#                 $80K - $120K               308             308
#                 Less than $40K             671             671
#                 Unknown                    225             225
# Post-Graduate   $120K +                     30              30
#                 $40K - $60K                111             111
#                 $60K - $80K                 77              77
#                 $80K - $120K                81              81
#                 Less than $40K             170             170
#                 Unknown                     47              47
# Uneducated      $120K +                    119             119
#                 $40K - $60K                249             249
#                 $60K - $80K                195             195
#                 $80K - $120K               217             217
#                 Less than $40K             522             522
#                 Unknown                    185             185
# Unknown         $120K +                    120             120
#                 $40K - $60K                269             269
#                 $60K - $80K                210             210
#                 $80K - $120K               219             219
#                 Less than $40K             556             556
#                 Unknown                    145             145
#
#                                  Total_Relationship_Count  \
# Education_Level Income_Category
# College         $120K +                                70
#                 $40K - $60K                           183
#                 $60K - $80K                           132
#                 $80K - $120K                          175
#                 Less than $40K                        345
#                 Unknown                               108
# Doctorate       $120K +                                37
#                 $40K - $60K                            70
#                 $60K - $80K                            59
#                 $80K - $120K                           57
#                 Less than $40K                        158
#                 Unknown                                70
# Graduate        $120K +                               204
#                 $40K - $60K                           553
#                 $60K - $80K                           422
#                 $80K - $120K                          478
#                 Less than $40K                       1139
#                 Unknown                               332
# High School     $120K +                               147
#                 $40K - $60K                           355
#                 $60K - $80K                           307
#                 $80K - $120K                          308
#                 Less than $40K                        671
#                 Unknown                               225
# Post-Graduate   $120K +                                30
#                 $40K - $60K                           111
#                 $60K - $80K                            77
#                 $80K - $120K                           81
#                 Less than $40K                        170
#                 Unknown                                47
# Uneducated      $120K +                               119
#                 $40K - $60K                           249
#                 $60K - $80K                           195
#                 $80K - $120K                          217
#                 Less than $40K                        522
#                 Unknown                               185
# Unknown         $120K +                               120
#                 $40K - $60K                           269
#                 $60K - $80K                           210
#                 $80K - $120K                          219
#                 Less than $40K                        556
#                 Unknown                               145
#
#                                  Months_Inactive_12_mon  \
# Education_Level Income_Category
# College         $120K +                              70
#                 $40K - $60K                         183
#                 $60K - $80K                         132
#                 $80K - $120K                        175
#                 Less than $40K                      345
#                 Unknown                             108
# Doctorate       $120K +                              37
#                 $40K - $60K                          70
#                 $60K - $80K                          59
#                 $80K - $120K                         57
#                 Less than $40K                      158
#                 Unknown                              70
# Graduate        $120K +                             204
#                 $40K - $60K                         553
#                 $60K - $80K                         422
#                 $80K - $120K                        478
#                 Less than $40K                     1139
#                 Unknown                             332
# High School     $120K +                             147
#                 $40K - $60K                         355
#                 $60K - $80K                         307
#                 $80K - $120K                        308
#                 Less than $40K                      671
#                 Unknown                             225
# Post-Graduate   $120K +                              30
#                 $40K - $60K                         111
#                 $60K - $80K                          77
#                 $80K - $120K                         81
#                 Less than $40K                      170
#                 Unknown                              47
# Uneducated      $120K +                             119
#                 $40K - $60K                         249
#                 $60K - $80K                         195
#                 $80K - $120K                        217
#                 Less than $40K                      522
#                 Unknown                             185
# Unknown         $120K +                             120
#                 $40K - $60K                         269
#                 $60K - $80K                         210
#                 $80K - $120K                        219
#                 Less than $40K                      556
#                 Unknown                             145
#
#                                  Contacts_Count_12_mon  Credit_Limit  \
# Education_Level Income_Category
# College         $120K +                             70            70
#                 $40K - $60K                        183           183
#                 $60K - $80K                        132           132
#                 $80K - $120K                       175           175
#                 Less than $40K                     345           345
#                 Unknown                            108           108
# Doctorate       $120K +                             37            37
#                 $40K - $60K                         70            70
#                 $60K - $80K                         59            59
#                 $80K - $120K                        57            57
#                 Less than $40K                     158           158
#                 Unknown                             70            70
# Graduate        $120K +                            204           204
#                 $40K - $60K                        553           553
#                 $60K - $80K                        422           422
#                 $80K - $120K                       478           478
#                 Less than $40K                    1139          1139
#                 Unknown                            332           332
# High School     $120K +                            147           147
#                 $40K - $60K                        355           355
#                 $60K - $80K                        307           307
#                 $80K - $120K                       308           308
#                 Less than $40K                     671           671
#                 Unknown                            225           225
# Post-Graduate   $120K +                             30            30
#                 $40K - $60K                        111           111
#                 $60K - $80K                         77            77
#                 $80K - $120K                        81            81
#                 Less than $40K                     170           170
#                 Unknown                             47            47
# Uneducated      $120K +                            119           119
#                 $40K - $60K                        249           249
#                 $60K - $80K                        195           195
#                 $80K - $120K                       217           217
#                 Less than $40K                     522           522
#                 Unknown                            185           185
# Unknown         $120K +                            120           120
#                 $40K - $60K                        269           269
#                 $60K - $80K                        210           210
#                 $80K - $120K                       219           219
#                 Less than $40K                     556           556
#                 Unknown                            145           145
#
#                                  Total_Revolving_Bal  Avg_Open_To_Buy  \
# Education_Level Income_Category
# College         $120K +                           70               70
#                 $40K - $60K                      183              183
#                 $60K - $80K                      132              132
#                 $80K - $120K                     175              175
#                 Less than $40K                   345              345
#                 Unknown                          108              108
# Doctorate       $120K +                           37               37
#                 $40K - $60K                       70               70
#                 $60K - $80K                       59               59
#                 $80K - $120K                      57               57
#                 Less than $40K                   158              158
#                 Unknown                           70               70
# Graduate        $120K +                          204              204
#                 $40K - $60K                      553              553
#                 $60K - $80K                      422              422
#                 $80K - $120K                     478              478
#                 Less than $40K                  1139             1139
#                 Unknown                          332              332
# High School     $120K +                          147              147
#                 $40K - $60K                      355              355
#                 $60K - $80K                      307              307
#                 $80K - $120K                     308              308
#                 Less than $40K                   671              671
#                 Unknown                          225              225
# Post-Graduate   $120K +                           30               30
#                 $40K - $60K                      111              111
#                 $60K - $80K                       77               77
#                 $80K - $120K                      81               81
#                 Less than $40K                   170              170
#                 Unknown                           47               47
# Uneducated      $120K +                          119              119
#                 $40K - $60K                      249              249
#                 $60K - $80K                      195              195
#                 $80K - $120K                     217              217
#                 Less than $40K                   522              522
#                 Unknown                          185              185
# Unknown         $120K +                          120              120
#                 $40K - $60K                      269              269
#                 $60K - $80K                      210              210
#                 $80K - $120K                     219              219
#                 Less than $40K                   556              556
#                 Unknown                          145              145
#
#                                  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# Education_Level Income_Category
# College         $120K +                            70               70
#                 $40K - $60K                       183              183
#                 $60K - $80K                       132              132
#                 $80K - $120K                      175              175
#                 Less than $40K                    345              345
#                 Unknown                           108              108
# Doctorate       $120K +                            37               37
#                 $40K - $60K                        70               70
#                 $60K - $80K                        59               59
#                 $80K - $120K                       57               57
#                 Less than $40K                    158              158
#                 Unknown                            70               70
# Graduate        $120K +                           204              204
#                 $40K - $60K                       553              553
#                 $60K - $80K                       422              422
#                 $80K - $120K                      478              478
#                 Less than $40K                   1139             1139
#                 Unknown                           332              332
# High School     $120K +                           147              147
#                 $40K - $60K                       355              355
#                 $60K - $80K                       307              307
#                 $80K - $120K                      308              308
#                 Less than $40K                    671              671
#                 Unknown                           225              225
# Post-Graduate   $120K +                            30               30
#                 $40K - $60K                       111              111
#                 $60K - $80K                        77               77
#                 $80K - $120K                       81               81
#                 Less than $40K                    170              170
#                 Unknown                            47               47
# Uneducated      $120K +                           119              119
#                 $40K - $60K                       249              249
#                 $60K - $80K                       195              195
#                 $80K - $120K                      217              217
#                 Less than $40K                    522              522
#                 Unknown                           185              185
# Unknown         $120K +                           120              120
#                 $40K - $60K                       269              269
#                 $60K - $80K                       210              210
#                 $80K - $120K                      219              219
#                 Less than $40K                    556              556
#                 Unknown                           145              145
#
#                                  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# Education_Level Income_Category
# College         $120K +                      70                   70
#                 $40K - $60K                 183                  183
#                 $60K - $80K                 132                  132
#                 $80K - $120K                175                  175
#                 Less than $40K              345                  345
#                 Unknown                     108                  108
# Doctorate       $120K +                      37                   37
#                 $40K - $60K                  70                   70
#                 $60K - $80K                  59                   59
#                 $80K - $120K                 57                   57
#                 Less than $40K              158                  158
#                 Unknown                      70                   70
# Graduate        $120K +                     204                  204
#                 $40K - $60K                 553                  553
#                 $60K - $80K                 422                  422
#                 $80K - $120K                478                  478
#                 Less than $40K             1139                 1139
#                 Unknown                     332                  332
# High School     $120K +                     147                  147
#                 $40K - $60K                 355                  355
#                 $60K - $80K                 307                  307
#                 $80K - $120K                308                  308
#                 Less than $40K              671                  671
#                 Unknown                     225                  225
# Post-Graduate   $120K +                      30                   30
#                 $40K - $60K                 111                  111
#                 $60K - $80K                  77                   77
#                 $80K - $120K                 81                   81
#                 Less than $40K              170                  170
#                 Unknown                      47                   47
# Uneducated      $120K +                     119                  119
#                 $40K - $60K                 249                  249
#                 $60K - $80K                 195                  195
#                 $80K - $120K                217                  217
#                 Less than $40K              522                  522
#                 Unknown                     185                  185
# Unknown         $120K +                     120                  120
#                 $40K - $60K                 269                  269
#                 $60K - $80K                 210                  210
#                 $80K - $120K                219                  219
#                 Less than $40K              556                  556
#                 Unknown                     145                  145
#
#                                  Avg_Utilization_Ratio  age_bin
# Education_Level Income_Category
# College         $120K +                             70       70
#                 $40K - $60K                        183      183
#                 $60K - $80K                        132      132
#                 $80K - $120K                       175      175
#                 Less than $40K                     345      345
#                 Unknown                            108      108
# Doctorate       $120K +                             37       37
#                 $40K - $60K                         70       70
#                 $60K - $80K                         59       59
#                 $80K - $120K                        57       57
#                 Less than $40K                     158      158
#                 Unknown                             70       70
# Graduate        $120K +                            204      204
#                 $40K - $60K                        553      553
#                 $60K - $80K                        422      422
#                 $80K - $120K                       478      478
#                 Less than $40K                    1139     1139
#                 Unknown                            332      332
# High School     $120K +                            147      147
#                 $40K - $60K                        355      355
#                 $60K - $80K                        307      307
#                 $80K - $120K                       308      308
#                 Less than $40K                     671      671
#                 Unknown                            225      225
# Post-Graduate   $120K +                             30       30
#                 $40K - $60K                        111      111
#                 $60K - $80K                         77       77
#                 $80K - $120K                        81       81
#                 Less than $40K                     170      170
#                 Unknown                             47       47
# Uneducated      $120K +                            119      119
#                 $40K - $60K                        249      249
#                 $60K - $80K                        195      195
#                 $80K - $120K                       217      217
#                 Less than $40K                     522      522
#                 Unknown                            185      185
# Unknown         $120K +                            120      120
#                 $40K - $60K                        269      269
#                 $60K - $80K                        210      210
#                 $80K - $120K                       219      219
#                 Less than $40K                     556      556
#                 Unknown                            145      145

# %%
df['Education_Level'].value_counts()
# Out:
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64

# %%
df[['Education_Level','Income_Category']].value_counts()
# Out:
# Education_Level  Income_Category
# Graduate         Less than $40K     1139
# High School      Less than $40K      671
# Unknown          Less than $40K      556
# Graduate         $40K - $60K         553
# Uneducated       Less than $40K      522
# Graduate         $80K - $120K        478
#                  $60K - $80K         422
# High School      $40K - $60K         355
# College          Less than $40K      345
# Graduate         Unknown             332
# High School      $80K - $120K        308
#                  $60K - $80K         307
# Unknown          $40K - $60K         269
# Uneducated       $40K - $60K         249
# High School      Unknown             225
# Unknown          $80K - $120K        219
# Uneducated       $80K - $120K        217
# Unknown          $60K - $80K         210
# Graduate         $120K +             204
# Uneducated       $60K - $80K         195
#                  Unknown             185
# College          $40K - $60K         183
#                  $80K - $120K        175
# Post-Graduate    Less than $40K      170
# Doctorate        Less than $40K      158
# High School      $120K +             147
# Unknown          Unknown             145
# College          $60K - $80K         132
# Unknown          $120K +             120
# Uneducated       $120K +             119
# Post-Graduate    $40K - $60K         111
# College          Unknown             108
# Post-Graduate    $80K - $120K         81
#                  $60K - $80K          77
# Doctorate        Unknown              70
#                  $40K - $60K          70
# College          $120K +              70
# Doctorate        $60K - $80K          59
#                  $80K - $120K         57
# Post-Graduate    Unknown              47
# Doctorate        $120K +              37
# Post-Graduate    $120K +              30
# dtype: int64

# %%
cnt = df[['Education_Level','Gender','Income_Category']].groupby(['Education_Level', 'Income_Category'])
cnt

# %%
temp = df[['Education_Level','Marital_Status','Income_Category']].groupby(['Education_Level', 'Income_Category'])

temp.count()
# Out:
#                                  Marital_Status
# Education_Level Income_Category
# College         $120K +                      70
#                 $40K - $60K                 183
#                 $60K - $80K                 132
#                 $80K - $120K                175
#                 Less than $40K              345
#                 Unknown                     108
# Doctorate       $120K +                      37
#                 $40K - $60K                  70
#                 $60K - $80K                  59
#                 $80K - $120K                 57
#                 Less than $40K              158
#                 Unknown                      70
# Graduate        $120K +                     204
#                 $40K - $60K                 553
#                 $60K - $80K                 422
#                 $80K - $120K                478
#                 Less than $40K             1139
#                 Unknown                     332
# High School     $120K +                     147
#                 $40K - $60K                 355
#                 $60K - $80K                 307
#                 $80K - $120K                308
#                 Less than $40K              671
#                 Unknown                     225
# Post-Graduate   $120K +                      30
#                 $40K - $60K                 111
#                 $60K - $80K                  77
#                 $80K - $120K                 81
#                 Less than $40K              170
#                 Unknown                      47
# Uneducated      $120K +                     119
#                 $40K - $60K                 249
#                 $60K - $80K                 195
#                 $80K - $120K                217
#                 Less than $40K              522
#                 Unknown                     185
# Unknown         $120K +                     120
#                 $40K - $60K                 269
#                 $60K - $80K                 210
#                 $80K - $120K                219
#                 Less than $40K              556
#                 Unknown                     145

# %%
temp = df[['Education_Level','Marital_Status','Income_Category']].groupby(['Education_Level', 'Income_Category'])

temp.count()
# Out:
#                                  Marital_Status
# Education_Level Income_Category
# College         $120K +                      70
#                 $40K - $60K                 183
#                 $60K - $80K                 132
#                 $80K - $120K                175
#                 Less than $40K              345
#                 Unknown                     108
# Doctorate       $120K +                      37
#                 $40K - $60K                  70
#                 $60K - $80K                  59
#                 $80K - $120K                 57
#                 Less than $40K              158
#                 Unknown                      70
# Graduate        $120K +                     204
#                 $40K - $60K                 553
#                 $60K - $80K                 422
#                 $80K - $120K                478
#                 Less than $40K             1139
#                 Unknown                     332
# High School     $120K +                     147
#                 $40K - $60K                 355
#                 $60K - $80K                 307
#                 $80K - $120K                308
#                 Less than $40K              671
#                 Unknown                     225
# Post-Graduate   $120K +                      30
#                 $40K - $60K                 111
#                 $60K - $80K                  77
#                 $80K - $120K                 81
#                 Less than $40K              170
#                 Unknown                      47
# Uneducated      $120K +                     119
#                 $40K - $60K                 249
#                 $60K - $80K                 195
#                 $80K - $120K                217
#                 Less than $40K              522
#                 Unknown                     185
# Unknown         $120K +                     120
#                 $40K - $60K                 269
#                 $60K - $80K                 210
#                 $80K - $120K                219
#                 Less than $40K              556
#                 Unknown                     145

# %% [markdown]
# **Education_Level, Marital_Status, Income_Category에서 "Unknown"이라는 결측치가 존재한다.**

# %%
df["Education_Level"].value_counts()
# Out:
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64

# %%
df["Marital_Status"].value_counts()
# Out:
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: Marital_Status, dtype: int64

# %%
df["Income_Category"].value_counts()
# Out:
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: Income_Category, dtype: int64

# %% [markdown]
# #####  **"Unknown"**에 대한 처리 방법은
#     1. "Unknown"도 하나의 category로 해석
#     2. "Unknown"값이 있는 행을 삭제하거나, 칼럼 자체(피처)를 삭제
#     3. 모델링을 활용하여 대체
#     4. 최빈값으로 대체
# ##### 정해진 답은 없고 여러가지로 시도해보는것이 가장 중요한것 같다.

# %% [markdown]
# **결측치로 처리 되지 않았던 Unknown을 np.nan으로 결측치로 처리를 해주고, 대표값(최빈값)으로 결측치를 대체해준다.**

# %%
df["Education_Level"].replace({"Unknown":np.nan,
                                "Graduate":0,
                                "Post-Graduate":1,
                                "Uneducated":2,
                                "College":3,
                                "Doctorate":4,
                                "High School":5,
                                 },inplace=True)

# %%
df["Marital_Status"].replace({"Unknown":np.nan,
                                "Married":0,
                                "Single":1,
                                "Divorced":2,
                                 },inplace=True)

# %%
df["Income_Category"].replace({"Unknown":np.nan,
                                "Less than $40K":0,
                                "$40K - $60K":1,
                                "$60K - $80K":2,
                                "$80K - $120K":3,
                                "$120K +":4,
                                 },inplace=True)

# %%
# Unknown이 결측치(np.nan)로 대체 된것을 확인할 수 있다.
df.isnull().sum()
# Out:
# CLIENTNUM                      0
# Attrition_Flag                 0
# Customer_Age                   0
# Gender                         0
# Dependent_count                0
# Education_Level             1519
# Marital_Status               749
# Income_Category             1112
# Card_Category                  0
# Months_on_book                 0
# Total_Relationship_Count       0
# Months_Inactive_12_mon         0
# Contacts_Count_12_mon          0
# Credit_Limit                   0
# Total_Revolving_Bal            0
# Avg_Open_To_Buy                0
# Total_Amt_Chng_Q4_Q1           0
# Total_Trans_Amt                0
# Total_Trans_Ct                 0
# Total_Ct_Chng_Q4_Q1            0
# Avg_Utilization_Ratio          0
# age_bin                        0
# dtype: int64

# %%
# 대표값 이용 결측치 대체 모듈 
from sklearn.impute import SimpleImputer
# 각 데이터에 사용할 인스턴스 생성
SI_mode =SimpleImputer(strategy = 'most_frequent') # 대표값 중 최빈값으로 결측치를 대체해준다.
# 학습
SI_mode.fit(df)
df = pd.DataFrame(SI_mode.transform(df),
                            columns = df.columns)

# %%
# 결측치가 대체를 확인할 수 있다.
df.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# age_bin                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  object
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  object
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  object
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  object
#  10  Total_Relationship_Count  10127 non-null  object
#  11  Months_Inactive_12_mon    10127 non-null  object
#  12  Contacts_Count_12_mon     10127 non-null  object
#  13  Credit_Limit              10127 non-null  object
#  14  Total_Revolving_Bal       10127 non-null  object
#  15  Avg_Open_To_Buy           10127 non-null  object
#  16  Total_Amt_Chng_Q4_Q1      10127 non-null  object
#  17  Total_Trans_Amt           10127 non-null  object
#  18  Total_Trans_Ct            10127 non-null  object
#  19  Total_Ct_Chng_Q4_Q1       10127 non-null  object
#  20  Avg_Utilization_Ratio     10127 non-null  object
#  21  age_bin                   10127 non-null  object
# dtypes: object(22)
# memory usage: 1.7+ MB

# %% [markdown]
# **중간에 dtype이 모두 object로 바뀌어서 에러가 났다.**

# %%
df[Numerics]=df[Numerics].astype("float")
df[Labels]=df[Labels].astype("int")
df[Orders]=df[Orders].astype("int")
df["Attrition_Flag"]=df["Attrition_Flag"].astype("int")

# 여기서 모든 데이터 타입을 float으로 바꾸어도 되는 것인지 궁금하다.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  object
#  1   Attrition_Flag            10127 non-null  int64
#  2   Customer_Age              10127 non-null  float64
#  3   Gender                    10127 non-null  int64
#  4   Dependent_count           10127 non-null  float64
#  5   Education_Level           10127 non-null  int64
#  6   Marital_Status            10127 non-null  int64
#  7   Income_Category           10127 non-null  int64
#  8   Card_Category             10127 non-null  int64
#  9   Months_on_book            10127 non-null  float64
#  10  Total_Relationship_Count  10127 non-null  float64
#  11  Months_Inactive_12_mon    10127 non-null  float64
#  12  Contacts_Count_12_mon     10127 non-null  float64
#  13  Credit_Limit              10127 non-null  float64
#  14  Total_Revolving_Bal       10127 non-null  float64
#  15  Avg_Open_To_Buy           10127 non-null  float64
#  16  Total_Amt_Chng_Q4_Q1      10127 non-null  float64
#  17  Total_Trans_Amt           10127 non-null  float64
#  18  Total_Trans_Ct            10127 non-null  float64
#  19  Total_Ct_Chng_Q4_Q1       10127 non-null  float64
#  20  Avg_Utilization_Ratio     10127 non-null  float64
#  21  age_bin                   10127 non-null  object
# dtypes: float64(14), int64(6), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# #### 4 (3) 상관관계가 높은 피처 제거

# %%
plt.subplots(figsize=(20,9))
plt.tick_params(axis='x',labelcolor='white')
plt.tick_params(axis='y',labelcolor='white')
sns.heatmap(df[Numerics].corr(),annot = True )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### (1) Month_on_book과 Customer_Age의 상관계수는 0.79로 높지만, 도메인 관점에서 완전히 다른 각각의 변수이므로 이 변수들을 삭제하지는 않는다.
# ##### (2) Credit_Limit와 Avg_Utilization_Ratio는 상관계수가 0.48이지만 같은 변수에서 파생되었기 때문에 둘중 하나의 변수만 나두고 나머지 하나는 삭제처리가 필요하다.

# %% [markdown]
# ##### -  'Avg_Open_To_Buy' = 'Credit_Limit' - 'Total_Revolving_Bal'
# ##### -  'Avg_Utilization_Ratio' = 'Total_Revolving_Bal'/ 'Credit_Limit'
# ##### -  Total_Trans_Amt, Total_Trans_Ct
# ##### - 'Total_Amt_Chng_Q4_Q1' , 'Total_Ct_Chng_Q4_Q1'
# #####
# ##### 피처간의 상관관계가 높은 변수들에서 어떤 변수들을 삭제할지를 결정할 때에는 타겟변수(종속변수)와의 상관관계까지 고려하여 타겟과의 상관관계가 높은 변수들을 선택한다.

# %% [markdown]
# **Attrition_Flag(범주형)과 수치형 피처 변수들의 상관관계를 파악하기 위해 pointbiserialr로 상관계수를 구한다.**

# %%
from scipy.stats import pointbiserialr

features = ['Avg_Open_To_Buy','Credit_Limit','Total_Revolving_Bal','Avg_Utilization_Ratio','Total_Trans_Amt','Total_Trans_Ct','Total_Amt_Chng_Q4_Q1','Total_Ct_Chng_Q4_Q1'] 

for feature in features:
    target_feature_corr = pointbiserialr(df['Attrition_Flag'], df[feature])
    print("Attrition_Flag와",feature,"의 상관관계는",target_feature_corr,"입니다.")
# Out:
# Attrition_Flag와 Avg_Open_To_Buy 의 상관관계는 PointbiserialrResult(correlation=-0.0002850774939378458, pvalue=0.9771160894272927) 입니다.
# Attrition_Flag와 Credit_Limit 의 상관관계는 PointbiserialrResult(correlation=-0.023872994836163616, pvalue=0.01628535720506713) 입니다.
# Attrition_Flag와 Total_Revolving_Bal 의 상관관계는 PointbiserialrResult(correlation=-0.2630528831292179, pvalue=6.630148455008398e-160) 입니다.
# Attrition_Flag와 Avg_Utilization_Ratio 의 상관관계는 PointbiserialrResult(correlation=-0.17841033156175928, pvalue=3.3576893281006543e-73) 입니다.
# Attrition_Flag와 Total_Trans_Amt 의 상관관계는 PointbiserialrResult(correlation=-0.16859838141009204, pvalue=1.8574386555805807e-65) 입니다.
# Attrition_Flag와 Total_Trans_Ct 의 상관관계는 PointbiserialrResult(correlation=-0.37140270118895313, pvalue=0.0) 입니다.
# Attrition_Flag와 Total_Amt_Chng_Q4_Q1 의 상관관계는 PointbiserialrResult(correlation=-0.13106284781448055, pvalue=4.836642703419737e-40) 입니다.
# Attrition_Flag와 Total_Ct_Chng_Q4_Q1 의 상관관계는 PointbiserialrResult(correlation=-0.29005400688091193, pvalue=1.647724784552201e-195) 입니다.

# %% [markdown]
# **여기서 p-value의 의미 해석하기**

# %% [markdown]
# **상관관계가 낮은 Avg_Open_To_Buy, Avg_Utilization_Ratio, Total_Trans_Amt, Total_Amt_Chng_Q4_Q1는 삭제(drop)**

# %%
df.drop(["CLIENTNUM", # 식별자 삭제
         "Avg_Open_To_Buy",
         "Avg_Utilization_Ratio",
         "Total_Trans_Amt",
         "age_bin",
         "Total_Amt_Chng_Q4_Q1"], axis=1,inplace=True)

# %% [markdown]
# #### 4 (4) 수치형 변수 log변환 정규화 변환

# %%
# 수치형 변수 중에 drop시킨 변수를 제외한 나머지 변수들을 모은 리스트를 만든다.
Numerics = ['Customer_Age','Dependent_count','Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
        'Total_Ct_Chng_Q4_Q1', 
       'Total_Trans_Ct']

# %%
# Credit_Limit의 분포를 히스토그램으로 시각화
sns.histplot(df["Credit_Limit"])
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Count'>

# %%
# 편향이 심한 Credit_Limit은 로그 변환을 해주도록한다.

df["Credit_Limit"]=np.log1p(df["Credit_Limit"])

# %%
df["Credit_Limit"]
# Out:
# 0        9.448727
# 1        9.018817
# 2        8.137103
# 3        8.105911
# 4        8.458928
#            ...
# 10122    8.295049
# 10123    8.361241
# 10124    8.596004
# 10125    8.572060
# 10126    9.248503
# Name: Credit_Limit, Length: 10127, dtype: float64

# %%
sns.histplot(df["Credit_Limit"])
# 편향이 조금 완화 된것을 확인 할 수 있다.
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Count'>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

for numeric in ['Customer_Age','Credit_Limit','Total_Revolving_Bal','Total_Ct_Chng_Q4_Q1','Total_Trans_Ct']:
    df[numeric] = scaler.fit_transform(df[numeric].values.reshape(-1,1))

# %%
# 수치형 데이터 표준화 확인
df[Numerics]
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# 0         -0.165406              3.0            39.0
# 1          0.333570              5.0            44.0
# 2          0.583058              3.0            36.0
# 3         -0.789126              4.0            34.0
# 4         -0.789126              3.0            21.0
# ...             ...              ...             ...
# 10122      0.458314              2.0            40.0
# 10123     -0.664382              2.0            25.0
# 10124     -0.290150              1.0            36.0
# 10125     -2.036565              2.0            36.0
# 10126     -0.414894              2.0            25.0
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                           5.0                     1.0
# 1                           6.0                     1.0
# 2                           4.0                     1.0
# 3                           3.0                     4.0
# 4                           5.0                     1.0
# ...                         ...                     ...
# 10122                       3.0                     2.0
# 10123                       4.0                     2.0
# 10124                       5.0                     3.0
# 10125                       4.0                     3.0
# 10126                       6.0                     2.0
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 0                        3.0      0.905210            -0.473422
# 1                        2.0      0.444695            -0.366667
# 2                        0.0     -0.499786            -1.426858
# 3                        1.0     -0.533199             1.661686
# 4                        0.0     -0.155051            -1.426858
# ...                      ...           ...                  ...
# 10122                    3.0     -0.330596             0.844455
# 10123                    3.0     -0.259693             1.255524
# 10124                    4.0     -0.008217            -1.426858
# 10125                    3.0     -0.033865            -1.426858
# 10126                    4.0      0.690732             0.979433
#
#        Total_Ct_Chng_Q4_Q1  Total_Trans_Ct
# 0                 3.834003       -0.973895
# 1                12.608573       -1.357340
# 2                 6.807864       -1.911206
# 3                 6.807864       -1.911206
# 4                 7.509325       -1.570365
# ...                    ...             ...
# 10122             0.608119        2.221481
# 10123            -0.122745        0.176440
# 10124             0.444305       -0.207005
# 10125             0.041070       -0.121795
# 10126            -0.265557       -0.164400
#
# [10127 rows x 10 columns]

# %% [markdown]
# ### 5. 모델링

# %% [markdown]
# #### 5 (1)지도학습

# %% [markdown]
# ### **모델링 >> smote >> 모델링 >> 하이퍼파라미터 수정 >> 모델링 >> 트레이드오프 수정>> 모델링 >> 모델링 선택**

# %%
X = df.iloc[:,1:] # 피처 변수 
y = df.iloc[:,0] # 타겟 변수 분리

# %%
X
# Out:
#        Customer_Age  Gender  Dependent_count  Education_Level  Marital_Status  \
# 0         -0.165406       0              3.0                5               0
# 1          0.333570       1              5.0                0               1
# 2          0.583058       0              3.0                0               0
# 3         -0.789126       1              4.0                5               0
# 4         -0.789126       0              3.0                2               0
# ...             ...     ...              ...              ...             ...
# 10122      0.458314       0              2.0                0               1
# 10123     -0.664382       0              2.0                0               2
# 10124     -0.290150       1              1.0                5               0
# 10125     -2.036565       0              2.0                0               0
# 10126     -0.414894       1              2.0                0               0
#
#        Income_Category  Card_Category  Months_on_book  \
# 0                    2              0            39.0
# 1                    0              0            44.0
# 2                    3              0            36.0
# 3                    0              0            34.0
# 4                    2              0            21.0
# ...                ...            ...             ...
# 10122                1              0            40.0
# 10123                1              0            25.0
# 10124                0              0            36.0
# 10125                1              0            36.0
# 10126                0              1            25.0
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                           5.0                     1.0
# 1                           6.0                     1.0
# 2                           4.0                     1.0
# 3                           3.0                     4.0
# 4                           5.0                     1.0
# ...                         ...                     ...
# 10122                       3.0                     2.0
# 10123                       4.0                     2.0
# 10124                       5.0                     3.0
# 10125                       4.0                     3.0
# 10126                       6.0                     2.0
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 0                        3.0      0.905210            -0.473422
# 1                        2.0      0.444695            -0.366667
# 2                        0.0     -0.499786            -1.426858
# 3                        1.0     -0.533199             1.661686
# 4                        0.0     -0.155051            -1.426858
# ...                      ...           ...                  ...
# 10122                    3.0     -0.330596             0.844455
# 10123                    3.0     -0.259693             1.255524
# 10124                    4.0     -0.008217            -1.426858
# 10125                    3.0     -0.033865            -1.426858
# 10126                    4.0      0.690732             0.979433
#
#        Total_Trans_Ct  Total_Ct_Chng_Q4_Q1
# 0           -0.973895             3.834003
# 1           -1.357340            12.608573
# 2           -1.911206             6.807864
# 3           -1.911206             6.807864
# 4           -1.570365             7.509325
# ...               ...                  ...
# 10122        2.221481             0.608119
# 10123        0.176440            -0.122745
# 10124       -0.207005             0.444305
# 10125       -0.121795             0.041070
# 10126       -0.164400            -0.265557
#
# [10127 rows x 15 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10122    0
# 10123    1
# 10124    1
# 10125    1
# 10126    1
# Name: Attrition_Flag, Length: 10127, dtype: int64

# %%
from sklearn.model_selection import train_test_split
# 학습과 데이터 세트로 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=11, stratify = X["Income_Category"])

# %% [markdown]
# **분류 분석 평가 지표 함수 - get_clf_eval() 함수**

# %% [markdown]
# **분류 분석을 측정하는 방법은 accuracy(정확도), precision(정밀도), recall(재현율) 등 여러가지 지표가 있는데, 타겟 변수의 비율 차이가 크면 정확도는 높게 나올 수 밖에 없어 신뢰할 수밖에 없다.**

# %% [markdown]
# **정밀도와 재현율 두 가지를 평가 지표로 활용해야 하는데, 고객 이탈 데이터는 잔류 고객은 이탈 고객으로 판단하여도 별 무리가 없으나, 이탈 고객을 잔류고객으로 판다하였을때는 손해를 보게 된다. 따라서 재현율을 높이는 방향으로 모델링을 진행한다.**

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score, roc_auc_score

def get_clf_eval(y_test,pred=None, pred_proba=None):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
    # ROC-AUC 추가
    roc_auc = roc_auc_score(y_test,pred_proba)
    print("오차행렬")
    print(confusion)
    print('정확도:{0:.4f}, 정밀도:{1:.4f}, 재현율:{2:.4f}, F1:{3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %% [markdown]
# **여러 가지 분류 분석**

# %%
from sklearn.tree import DecisionTreeClassifier # 의사결정 나무
from sklearn.ensemble import RandomForestClassifier # 랜덤 포레스트
from sklearn.linear_model import LogisticRegression # 로지스틱 회귀
from sklearn.neighbors import KNeighborsClassifier # k-최근접이웃
from sklearn.ensemble import GradientBoostingClassifier # GBM
from xgboost import XGBClassifier # XGBM


# 사이킷런 Classifier 클래스 생성
dt_clf = DecisionTreeClassifier(random_state=11)
rf_clf = RandomForestClassifier(random_state=11)
lr_clf = LogisticRegression()
kn_clf = KNeighborsClassifier(n_neighbors=5)
gb_clf = GradientBoostingClassifier(random_state=11)

# DecisionTreeClassifier 학습/예측/평가
dt_clf.fit(X_train, y_train)
dt_pred = dt_clf.predict(X_test)
dt_pred_proba = dt_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, dt_pred, dt_pred_proba)

# RandomForestClassifier
rf_clf.fit(X_train, y_train)
rf_pred = rf_clf.predict(X_test)
rf_pred_proba = rf_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, rf_pred, rf_pred_proba)

# LogistRegression
lr_clf.fit(X_train, y_train)
lr_pred = lr_clf.predict(X_test)
lr_pred_proba = lr_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, lr_pred, lr_pred_proba)

# KNeighborsClassifier
kn_clf.fit(X_train, y_train)
kn_pred = kn_clf.predict(X_test)
kn_pred_proba = kn_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, kn_pred, kn_pred_proba)

# GBM
gb_clf.fit(X_train, y_train)
gb_pred = gb_clf.predict(X_test)
gb_pred_proba = gb_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, gb_pred, gb_pred_proba)

# XGBM
xgb_wrapper = XGBClassifier()
xgb_wrapper.fit(X_train, y_train)
w_preds = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:,1]
get_clf_eval(y_test, w_preds, w_pred_proba)
# Out:
# 오차행렬
# [[1597  104]
#  [ 112  213]]
# 정확도:0.8934, 정밀도:0.6719, 재현율:0.6554, F1:0.6636, AUC:0.7971
# 오차행렬
# [[1676   25]
#  [ 101  224]]
# 정확도:0.9378, 정밀도:0.8996, 재현율:0.6892, F1:0.7805, AUC:0.9541
# 오차행렬
# [[1644   57]
#  [ 149  176]]
# 정확도:0.8983, 정밀도:0.7554, 재현율:0.5415, F1:0.6308, AUC:0.8842
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 오차행렬
# [[1670   31]
#  [ 184  141]]
# 정확도:0.8939, 정밀도:0.8198, 재현율:0.4338, F1:0.5674, AUC:0.8456
# 오차행렬
# [[1665   36]
#  [ 100  225]]
# 정확도:0.9329, 정밀도:0.8621, 재현율:0.6923, F1:0.7679, AUC:0.9538
# [13:14:41] WARNING: /Users/ktietz/demo/mc3/conda-bld/xgboost-split_1628682908089/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 오차행렬
# [[1660   41]
#  [  85  240]]
# 정확도:0.9378, 정밀도:0.8541, 재현율:0.7385, F1:0.7921, AUC:0.9626

# %% [markdown]
# **결정 트리(Decision Tree)**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# DecisionTree Classifier 생성
dt_clf = DecisionTreeClassifier(random_state=156)

# 학습과 데이터 세트로 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=11, stratify = y)

# DecisionTreeClassifier 학습
dt_clf.fit(X_train,y_train)

# DecisionTreeClassifier 학습/예측/평가
dt_clf.fit(X_train, y_train)
dt_pred = dt_clf.predict(X_test)
dt_pred_proba = dt_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, dt_pred, dt_pred_proba)


# DecisionTreeClassifier의 하이퍼 파라미터 추출
print('\nDecisionTreeClassifier 기본 하이퍼 파라미터:\n', dt_clf.get_params())
# Out:
# 오차행렬
# [[1601  100]
#  [ 106  219]]
# 정확도:0.8983, 정밀도:0.6865, 재현율:0.6738, F1:0.6801, AUC:0.8075
#
# DecisionTreeClassifier 기본 하이퍼 파라미터:
#  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': 156, 'splitter': 'best'}

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=0)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)
print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트', X_train.shape, y_train.shape)
print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트', X_train_over.shape, y_train_over.shape)

# %%
X_train = X_train_over
y_train = y_train_over

# %%
# DecisionTreeClassifier 학습/예측/평가
dt_clf.fit(X_train, y_train)
dt_pred = dt_clf.predict(X_test)
dt_pred_proba = dt_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, dt_pred, dt_pred_proba)

# RandomForestClassifier
rf_clf.fit(X_train, y_train)
rf_pred = rf_clf.predict(X_test)
rf_pred_proba = rf_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, rf_pred, rf_pred_proba)

# LogistRegression
lr_clf.fit(X_train, y_train)
lr_pred = lr_clf.predict(X_test)
lr_pred_proba = lr_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, lr_pred, lr_pred_proba)

# KNeighborsClassifier
kn_clf.fit(X_train, y_train)
kn_pred = kn_clf.predict(X_test)
kn_pred_proba = kn_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, kn_pred, kn_pred_proba)

# GBM
gb_clf.fit(X_train, y_train)
gb_pred = gb_clf.predict(X_test)
gb_pred_proba = gb_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, gb_pred, gb_pred_proba)

# XGBM
xgb_wrapper = XGBClassifier()
xgb_wrapper.fit(X_train, y_train)
w_preds = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:,1]
get_clf_eval(y_test, w_preds, w_pred_proba)
# Out:
# 오차행렬
# [[1557  144]
#  [  89  236]]
# 정확도:0.8850, 정밀도:0.6211, 재현율:0.7262, F1:0.6695, AUC:0.8207
# 오차행렬
# [[1643   58]
#  [  75  250]]
# 정확도:0.9344, 정밀도:0.8117, 재현율:0.7692, F1:0.7899, AUC:0.9549
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 오차행렬
# [[1421  280]
#  [  81  244]]
# 정확도:0.8218, 정밀도:0.4656, 재현율:0.7508, F1:0.5748, AUC:0.8793
# 오차행렬
# [[1383  318]
#  [  81  244]]
# 정확도:0.8031, 정밀도:0.4342, 재현율:0.7508, F1:0.5502, AUC:0.8535
# 오차행렬
# [[1625   76]
#  [  70  255]]
# 정확도:0.9279, 정밀도:0.7704, 재현율:0.7846, F1:0.7774, AUC:0.9552
# [13:16:25] WARNING: /Users/ktietz/demo/mc3/conda-bld/xgboost-split_1628682908089/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 오차행렬
# [[1653   48]
#  [  75  250]]
# 정확도:0.9393, 정밀도:0.8389, 재현율:0.7692, F1:0.8026, AUC:0.9613

# %% [markdown]
# **결정 트리의 트리깊이(Tree Depth)가 예측 정확도에 주는 영향을 살펴보자. 결정 트리의 경우 분류를 위해 리프 노드(클래스 결정 노드)가 될 수 있는 적합한 수준이 될 때까지 계속해서 트리의 분할을 수행하면서 깊이가 깊어진다. GridSearchCV를 이용해 사이킷런 결정 트리의 깊이를 조절할 수 있는 하이퍼 파라미터인 max_depth 값을 변화시키면서 예측 성능을 확인한다. max_depth를 6,8,10,12,16,20,24로 늘려가면서 예측 성능을 측정한다.**

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'max_depth':[6,8,10,12,16,20,24]
}

grid_cv = GridSearchCV(dt_clf, param_grid=params, scoring='recall', cv=5, verbose=1)
grid_cv.fit(X_train, y_train)
print('GridSearchCV 최고 평균 재현율 수치 : {0:.4f}'.format(grid_cv.best_score_))
print('GridSearchCV 최적 하이퍼 파라미터 :',grid_cv.best_params_)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# GridSearchCV 최고 평균 재현율 수치 : 0.6874
# GridSearchCV 최적 하이퍼 파라미터 : {'max_depth': 20}

# %% [markdown]
# **max_depth가 20일때 재현율이 0.687380으로 가장 높다.**

# %%
best_dt_clf = grid_cv.best_estimator_
pred1 = best_dt_clf.predict(X_test)
pred_proba1 = best_dt_clf.predict_proba(X_test)[:,1]
dt_results = get_clf_eval(y_test, pred1, pred_proba1)
# Out:
# 오차행렬
# [[1598  103]
#  [ 108  217]]
# 정확도:0.8959, 정밀도:0.6781, 재현율:0.6677, F1:0.6729, AUC:0.8033

# %% [markdown]
# **하이퍼 파라미터 튜닝을 했지만, 전후 차이가 크지 않다.**

# %%
from sklearn.tree import export_graphviz

# export_graphviz()의 호출 결과로 out_file로 지정된 tree.dot 파일을 생성함
export_graphviz(best_dt_clf, out_file="tree.dot", class_names=['Existiong_Customer','Attrited_Customer'], feature_names = X.keys(), impurity=True, filled=True)

# %%
import graphviz
# 위에서 생성된 tree.dot 파일을 Graphviz가 읽어서 주피터 노프북상에서 시각화
with open('tree.dot') as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
import seaborn as sns
import numpy as np
# %matplotlib inline

# feature importance 추출
print("Feature importances:\n{0}".format(np.round(best_dt_clf.feature_importances_, 3)))

# feature 별 importance 매핑
for name, value in zip(X.keys(), best_dt_clf.feature_importances_):
    print('{0}:{1:.3f}'.format(name,value))
    
# feature importance를 column 별로 시각화하기
sns.barplot(x=dt_clf.feature_importances_, y=X.keys())
# Out:
# Feature importances:
# [0.048 0.01  0.019 0.023 0.013 0.01  0.005 0.028 0.104 0.04  0.04  0.074
#  0.22  0.256 0.111]
# Customer_Age:0.048
# Gender:0.010
# Dependent_count:0.019
# Education_Level:0.023
# Marital_Status:0.013
# Income_Category:0.010
# Card_Category:0.005
# Months_on_book:0.028
# Total_Relationship_Count:0.104
# Months_Inactive_12_mon:0.040
# Contacts_Count_12_mon:0.040
# Credit_Limit:0.074
# Total_Revolving_Bal:0.220
# Total_Trans_Ct:0.256
# Total_Ct_Chng_Q4_Q1:0.111
# <AxesSubplot:>

# %% [markdown]
# **GBM**

# %%
from sklearn.ensemble import GradientBoostingClassifier
import time

# GBM 수행 시간 측정. 시작 시간 설정
start_time = time.time()

gb_clf = GradientBoostingClassifier(random_state=0)
gb_clf.fit(X_train, y_train)
gb_pred = gb_clf.predict(X_test)
gb_pred_proba = gb_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, gb_pred, gb_pred_proba)

print("GBM 수행 시간 :{0:.1F}초".format(time.time()-start_time))
# Out:
# 오차행렬
# [[1665   36]
#  [ 100  225]]
# 정확도:0.9329, 정밀도:0.8621, 재현율:0.6923, F1:0.7679, AUC:0.9537
# GBM 수행 시간 :0.9초

# %%
import xgboost as xgb
from xgboost import plot_importance

dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test, label=y_test)

# %%
params = {
    'max_depth':3,
    'objective':'binary:logistic',
    'eval_metric':'logloss',
    'early_stoppings':100
}
num_rounds = 400

# %%
# train 데이터 세트는 'train', evaluation(test) 데이터 세트는 'eval'로 명기합니다.
wlist = [(dtrain, 'train'),(dtest,'eval')]
# 하이퍼 파라미터와 early stopping 파라미터를 train() 함수의 파라미터로 전달
xgb_model = xgb.train(params = params, dtrain=dtrain, num_boost_round=num_rounds,\
                     early_stopping_rounds=100, evals=wlist)
# Out:
# [13:06:08] WARNING: /Users/ktietz/demo/mc3/conda-bld/xgboost-split_1628682908089/work/src/learner.cc:541:
# Parameters: { early_stoppings } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-logloss:0.51576	eval-logloss:0.51707
# [1]	train-logloss:0.41818	eval-logloss:0.41870
# [2]	train-logloss:0.35767	eval-logloss:0.36065
# [3]	train-logloss:0.31477	eval-logloss:0.31976
# [4]	train-logloss:0.28596	eval-logloss:0.28947
# [5]	train-logloss:0.26427	eval-logloss:0.26887
# [6]	train-logloss:0.24826	eval-logloss:0.25390
# [7]	train-logloss:0.23600	eval-logloss:0.24402
# [8]	train-logloss:0.22601	eval-logloss:0.23338
# [9]	train-logloss:0.21816	eval-logloss:0.22740
# [10]	train-logloss:0.21106	eval-logloss:0.22129
# [11]	train-logloss:0.20456	eval-logloss:0.21626
# [12]	train-logloss:0.19931	eval-logloss:0.21115
# [13]	train-logloss:0.19539	eval-logloss:0.20780
# [14]	train-logloss:0.19118	eval-logloss:0.20519
# [15]	train-logloss:0.18745	eval-logloss:0.20213
# [16]	train-logloss:0.18456	eval-logloss:0.19984
# [17]	train-logloss:0.18231	eval-logloss:0.19817
# [18]	train-logloss:0.17994	eval-logloss:0.19671
# [19]	train-logloss:0.17755	eval-logloss:0.19490
# [20]	train-logloss:0.17565	eval-logloss:0.19334
# [21]	train-logloss:0.17290	eval-logloss:0.19018
# [22]	train-logloss:0.17131	eval-logloss:0.18864
# [23]	train-logloss:0.16962	eval-logloss:0.18782
# [24]	train-logloss:0.16857	eval-logloss:0.18743
# [25]	train-logloss:0.16671	eval-logloss:0.18653
# [26]	train-logloss:0.16546	eval-logloss:0.18455
# [27]	train-logloss:0.16325	eval-logloss:0.18287
# [28]	train-logloss:0.16240	eval-logloss:0.18224
# [29]	train-logloss:0.16129	eval-logloss:0.18155
# [30]	train-logloss:0.16067	eval-logloss:0.18097
# [31]	train-logloss:0.15854	eval-logloss:0.17916
# [32]	train-logloss:0.15728	eval-logloss:0.17857
# [33]	train-logloss:0.15629	eval-logloss:0.17766
# [34]	train-logloss:0.15560	eval-logloss:0.17680
# [35]	train-logloss:0.15515	eval-logloss:0.17646
# [36]	train-logloss:0.15177	eval-logloss:0.17255
# [37]	train-logloss:0.15063	eval-logloss:0.17180
# [38]	train-logloss:0.14996	eval-logloss:0.17118
# [39]	train-logloss:0.14927	eval-logloss:0.17072
# [40]	train-logloss:0.14856	eval-logloss:0.17017
# [41]	train-logloss:0.14786	eval-logloss:0.17032
# [42]	train-logloss:0.14752	eval-logloss:0.17020
# [43]	train-logloss:0.14611	eval-logloss:0.17012
# [44]	train-logloss:0.14440	eval-logloss:0.16895
# [45]	train-logloss:0.14389	eval-logloss:0.16913
# [46]	train-logloss:0.14330	eval-logloss:0.16901
# [47]	train-logloss:0.14299	eval-logloss:0.16889
# [48]	train-logloss:0.14276	eval-logloss:0.16865
# [49]	train-logloss:0.14233	eval-logloss:0.16822
# [50]	train-logloss:0.14170	eval-logloss:0.16786
# [51]	train-logloss:0.14077	eval-logloss:0.16742
# [52]	train-logloss:0.13978	eval-logloss:0.16660
# [53]	train-logloss:0.13917	eval-logloss:0.16657
# [54]	train-logloss:0.13895	eval-logloss:0.16651
# [55]	train-logloss:0.13803	eval-logloss:0.16718
# [56]	train-logloss:0.13787	eval-logloss:0.16706
# [57]	train-logloss:0.13728	eval-logloss:0.16697
# [58]	train-logloss:0.13694	eval-logloss:0.16692
# [59]	train-logloss:0.13636	eval-logloss:0.16643
# [60]	train-logloss:0.13619	eval-logloss:0.16625
# [61]	train-logloss:0.13601	eval-logloss:0.16633
# [62]	train-logloss:0.13528	eval-logloss:0.16552
# [63]	train-logloss:0.13407	eval-logloss:0.16511
# [64]	train-logloss:0.13333	eval-logloss:0.16511
# [65]	train-logloss:0.13251	eval-logloss:0.16514
# [66]	train-logloss:0.13225	eval-logloss:0.16508
# [67]	train-logloss:0.13115	eval-logloss:0.16447
# [68]	train-logloss:0.13103	eval-logloss:0.16421
# [69]	train-logloss:0.13010	eval-logloss:0.16347
# [70]	train-logloss:0.12923	eval-logloss:0.16348
# [71]	train-logloss:0.12890	eval-logloss:0.16338
# [72]	train-logloss:0.12851	eval-logloss:0.16354
# [73]	train-logloss:0.12824	eval-logloss:0.16373
# [74]	train-logloss:0.12764	eval-logloss:0.16339
# [75]	train-logloss:0.12752	eval-logloss:0.16345
# [76]	train-logloss:0.12721	eval-logloss:0.16419
# [77]	train-logloss:0.12638	eval-logloss:0.16328
# [78]	train-logloss:0.12570	eval-logloss:0.16283
# [79]	train-logloss:0.12546	eval-logloss:0.16294
# [80]	train-logloss:0.12492	eval-logloss:0.16254
# [81]	train-logloss:0.12427	eval-logloss:0.16231
# [82]	train-logloss:0.12312	eval-logloss:0.16169
# [83]	train-logloss:0.12278	eval-logloss:0.16189
# [84]	train-logloss:0.12215	eval-logloss:0.16160
# [85]	train-logloss:0.12175	eval-logloss:0.16160
# [86]	train-logloss:0.12117	eval-logloss:0.16114
# [87]	train-logloss:0.12095	eval-logloss:0.16113
# [88]	train-logloss:0.12086	eval-logloss:0.16121
# [89]	train-logloss:0.12034	eval-logloss:0.16081
# [90]	train-logloss:0.11970	eval-logloss:0.16102
# [91]	train-logloss:0.11947	eval-logloss:0.16105
# [92]	train-logloss:0.11866	eval-logloss:0.16062
# [93]	train-logloss:0.11801	eval-logloss:0.16066
# [94]	train-logloss:0.11749	eval-logloss:0.16068
# [95]	train-logloss:0.11737	eval-logloss:0.16075
# [96]	train-logloss:0.11696	eval-logloss:0.16070
# [97]	train-logloss:0.11637	eval-logloss:0.16042
# [98]	train-logloss:0.11571	eval-logloss:0.16002
# [99]	train-logloss:0.11537	eval-logloss:0.15999
# [100]	train-logloss:0.11507	eval-logloss:0.16023
# [101]	train-logloss:0.11464	eval-logloss:0.16046
# [102]	train-logloss:0.11400	eval-logloss:0.15997
# [103]	train-logloss:0.11345	eval-logloss:0.15934
# [104]	train-logloss:0.11296	eval-logloss:0.15950
# [105]	train-logloss:0.11289	eval-logloss:0.15954
# [106]	train-logloss:0.11281	eval-logloss:0.15959
# [107]	train-logloss:0.11270	eval-logloss:0.15963
# [108]	train-logloss:0.11263	eval-logloss:0.15948
# [109]	train-logloss:0.11189	eval-logloss:0.15986
# [110]	train-logloss:0.11133	eval-logloss:0.15929
# [111]	train-logloss:0.11108	eval-logloss:0.15930
# [112]	train-logloss:0.11055	eval-logloss:0.15950
# [113]	train-logloss:0.10988	eval-logloss:0.15890
# [114]	train-logloss:0.10968	eval-logloss:0.15902
# [115]	train-logloss:0.10928	eval-logloss:0.15904
# [116]	train-logloss:0.10880	eval-logloss:0.15835
# [117]	train-logloss:0.10862	eval-logloss:0.15839
# [118]	train-logloss:0.10856	eval-logloss:0.15843
# [119]	train-logloss:0.10845	eval-logloss:0.15841
# [120]	train-logloss:0.10802	eval-logloss:0.15817
# [121]	train-logloss:0.10759	eval-logloss:0.15837
# [122]	train-logloss:0.10728	eval-logloss:0.15866
# [123]	train-logloss:0.10661	eval-logloss:0.15901
# [124]	train-logloss:0.10592	eval-logloss:0.15827
# [125]	train-logloss:0.10524	eval-logloss:0.15789
# [126]	train-logloss:0.10470	eval-logloss:0.15822
# [127]	train-logloss:0.10427	eval-logloss:0.15778
# [128]	train-logloss:0.10400	eval-logloss:0.15785
# [129]	train-logloss:0.10342	eval-logloss:0.15768
# [130]	train-logloss:0.10336	eval-logloss:0.15771
# [131]	train-logloss:0.10285	eval-logloss:0.15733
# [132]	train-logloss:0.10260	eval-logloss:0.15743
# [133]	train-logloss:0.10222	eval-logloss:0.15758
# [134]	train-logloss:0.10157	eval-logloss:0.15720
# [135]	train-logloss:0.10133	eval-logloss:0.15743
# [136]	train-logloss:0.10094	eval-logloss:0.15761
# [137]	train-logloss:0.10080	eval-logloss:0.15760
# [138]	train-logloss:0.10066	eval-logloss:0.15746
# [139]	train-logloss:0.10046	eval-logloss:0.15751
# [140]	train-logloss:0.09994	eval-logloss:0.15753
# [141]	train-logloss:0.09931	eval-logloss:0.15844
# [142]	train-logloss:0.09884	eval-logloss:0.15822
# [143]	train-logloss:0.09848	eval-logloss:0.15804
# [144]	train-logloss:0.09809	eval-logloss:0.15788
# [145]	train-logloss:0.09767	eval-logloss:0.15735
# [146]	train-logloss:0.09745	eval-logloss:0.15715
# [147]	train-logloss:0.09725	eval-logloss:0.15721
# [148]	train-logloss:0.09683	eval-logloss:0.15737
# [149]	train-logloss:0.09634	eval-logloss:0.15705
# [150]	train-logloss:0.09593	eval-logloss:0.15715
# [151]	train-logloss:0.09576	eval-logloss:0.15713
# [152]	train-logloss:0.09554	eval-logloss:0.15733
# [153]	train-logloss:0.09542	eval-logloss:0.15742
# [154]	train-logloss:0.09529	eval-logloss:0.15759
# [155]	train-logloss:0.09489	eval-logloss:0.15777
# [156]	train-logloss:0.09460	eval-logloss:0.15750
# [157]	train-logloss:0.09420	eval-logloss:0.15746
# [158]	train-logloss:0.09373	eval-logloss:0.15762
# [159]	train-logloss:0.09331	eval-logloss:0.15723
# [160]	train-logloss:0.09281	eval-logloss:0.15731
# [161]	train-logloss:0.09236	eval-logloss:0.15757
# [162]	train-logloss:0.09202	eval-logloss:0.15767
# [163]	train-logloss:0.09175	eval-logloss:0.15761
# [164]	train-logloss:0.09158	eval-logloss:0.15737
# [165]	train-logloss:0.09132	eval-logloss:0.15757
# [166]	train-logloss:0.09120	eval-logloss:0.15810
# [167]	train-logloss:0.09079	eval-logloss:0.15793
# [168]	train-logloss:0.09036	eval-logloss:0.15821
# [169]	train-logloss:0.08986	eval-logloss:0.15865
# [170]	train-logloss:0.08950	eval-logloss:0.15920
# [171]	train-logloss:0.08941	eval-logloss:0.15932
# [172]	train-logloss:0.08900	eval-logloss:0.15977
# [173]	train-logloss:0.08855	eval-logloss:0.15954
# [174]	train-logloss:0.08815	eval-logloss:0.15988
# [175]	train-logloss:0.08795	eval-logloss:0.16002
# [176]	train-logloss:0.08789	eval-logloss:0.16000
# [177]	train-logloss:0.08780	eval-logloss:0.16007
# [178]	train-logloss:0.08752	eval-logloss:0.15987
# [179]	train-logloss:0.08735	eval-logloss:0.15979
# [180]	train-logloss:0.08696	eval-logloss:0.15982
# [181]	train-logloss:0.08685	eval-logloss:0.15981
# [182]	train-logloss:0.08669	eval-logloss:0.15960
# [183]	train-logloss:0.08627	eval-logloss:0.15989
# [184]	train-logloss:0.08605	eval-logloss:0.16016
# [185]	train-logloss:0.08567	eval-logloss:0.16026
# [186]	train-logloss:0.08540	eval-logloss:0.16054
# [187]	train-logloss:0.08517	eval-logloss:0.16021
# [188]	train-logloss:0.08495	eval-logloss:0.16011
# [189]	train-logloss:0.08480	eval-logloss:0.16022
# [190]	train-logloss:0.08416	eval-logloss:0.16022
# [191]	train-logloss:0.08387	eval-logloss:0.16045
# [192]	train-logloss:0.08370	eval-logloss:0.16020
# [193]	train-logloss:0.08333	eval-logloss:0.15994
# [194]	train-logloss:0.08311	eval-logloss:0.16006
# [195]	train-logloss:0.08282	eval-logloss:0.16012
# [196]	train-logloss:0.08256	eval-logloss:0.16018
# [197]	train-logloss:0.08235	eval-logloss:0.15986
# [198]	train-logloss:0.08211	eval-logloss:0.15958
# [199]	train-logloss:0.08170	eval-logloss:0.15946
# [200]	train-logloss:0.08155	eval-logloss:0.15967
# [201]	train-logloss:0.08139	eval-logloss:0.15943
# [202]	train-logloss:0.08125	eval-logloss:0.15911
# [203]	train-logloss:0.08096	eval-logloss:0.15877
# [204]	train-logloss:0.08074	eval-logloss:0.15847
# [205]	train-logloss:0.08033	eval-logloss:0.15827
# [206]	train-logloss:0.08017	eval-logloss:0.15850
# [207]	train-logloss:0.07984	eval-logloss:0.15890
# [208]	train-logloss:0.07972	eval-logloss:0.15910
# [209]	train-logloss:0.07948	eval-logloss:0.15888
# [210]	train-logloss:0.07946	eval-logloss:0.15893
# [211]	train-logloss:0.07939	eval-logloss:0.15905
# [212]	train-logloss:0.07909	eval-logloss:0.15935
# [213]	train-logloss:0.07876	eval-logloss:0.15932
# [214]	train-logloss:0.07863	eval-logloss:0.15934
# [215]	train-logloss:0.07844	eval-logloss:0.15935
# [216]	train-logloss:0.07822	eval-logloss:0.15931
# [217]	train-logloss:0.07805	eval-logloss:0.15932
# [218]	train-logloss:0.07777	eval-logloss:0.15907
# [219]	train-logloss:0.07740	eval-logloss:0.15913
# [220]	train-logloss:0.07709	eval-logloss:0.15893
# [221]	train-logloss:0.07676	eval-logloss:0.15919
# [222]	train-logloss:0.07644	eval-logloss:0.15960
# [223]	train-logloss:0.07617	eval-logloss:0.15959
# [224]	train-logloss:0.07594	eval-logloss:0.15991
# [225]	train-logloss:0.07573	eval-logloss:0.15976
# [226]	train-logloss:0.07551	eval-logloss:0.15991
# [227]	train-logloss:0.07517	eval-logloss:0.16000
# [228]	train-logloss:0.07482	eval-logloss:0.16023
# [229]	train-logloss:0.07460	eval-logloss:0.16044
# [230]	train-logloss:0.07455	eval-logloss:0.16052
# [231]	train-logloss:0.07429	eval-logloss:0.16097
# [232]	train-logloss:0.07410	eval-logloss:0.16130
# [233]	train-logloss:0.07379	eval-logloss:0.16110
# [234]	train-logloss:0.07344	eval-logloss:0.16079
# [235]	train-logloss:0.07335	eval-logloss:0.16087
# [236]	train-logloss:0.07309	eval-logloss:0.16107
# [237]	train-logloss:0.07284	eval-logloss:0.16115
# [238]	train-logloss:0.07272	eval-logloss:0.16116
# [239]	train-logloss:0.07231	eval-logloss:0.16089
# [240]	train-logloss:0.07207	eval-logloss:0.16112
# [241]	train-logloss:0.07194	eval-logloss:0.16142
# [242]	train-logloss:0.07165	eval-logloss:0.16181
# [243]	train-logloss:0.07149	eval-logloss:0.16188
# [244]	train-logloss:0.07114	eval-logloss:0.16219
# [245]	train-logloss:0.07089	eval-logloss:0.16246
# [246]	train-logloss:0.07057	eval-logloss:0.16241
# [247]	train-logloss:0.07027	eval-logloss:0.16245
# [248]	train-logloss:0.07015	eval-logloss:0.16261
# [249]	train-logloss:0.06997	eval-logloss:0.16253

# %%
pred_probs = xgb_model.predict(dtest)
print('predict() 수행 결과값을 10개만 표시, 예측 확률값으로 표시됨')
print(np.round(pred_probs[:10],3))

# 예측 확률이 0.5 보다 크면 1, 그렇지 않으면 0 으로 예측값 결정해 리스트 객체인 preds에 저장
preds =[1 if x > 0.5 else 0 for x in pred_probs]
print('예측값 10개만 표시:', preds[:10])
# Out:
# predict() 수행 결과값을 10개만 표시, 예측 확률값으로 표시됨
# [0.999 0.006 0.    0.    0.947 0.    0.    0.004 0.003 0.093]
# 예측값 10개만 표시: [1, 0, 0, 0, 1, 0, 0, 0, 0, 0]

# %%
get_clf_eval(y_test, preds, pred_probs)
# Out:
# 오차행렬
# [[1657   44]
#  [  79  246]]
# 정확도:0.9393, 정밀도:0.8483, 재현율:0.7569, F1:0.8000, AUC:0.9621

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt 
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10,12))
plot_importance(xgb_model, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
# 사이킷런 래퍼 XGBoost 클래스인 XGBClassifier 임포트
from xgboost import XGBClassifier

xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3)
xgb_wrapper.fit(X_train, y_train)
w_preds = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:,1]

get_clf_eval(y_test, w_preds, w_pred_proba)
# Out:
# [13:06:09] WARNING: /Users/ktietz/demo/mc3/conda-bld/xgboost-split_1628682908089/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 오차행렬
# [[1667   34]
#  [  80  245]]
# 정확도:0.9437, 정밀도:0.8781, 재현율:0.7538, F1:0.8113, AUC:0.9616

# %%
# 사이킷런 래퍼 XGBoost 클래스인 XGBClassifier 임포트
from xgboost import XGBClassifier

xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3)
evals =[(X_test, y_test)]
xgb_wrapper.fit(X_train, y_train, early_stopping_rounds=100, eval_metric="logloss",
               eval_set=evals, verbose=True)
ws100_preds = xgb_wrapper.predict(X_test)
ws100_pred_proba = xgb_wrapper.predict_proba(X_test)[:,1]

get_clf_eval(y_test, ws100_preds, ws100_pred_proba)
# Out:
# [0]	validation_0-logloss:0.62768
# [1]	validation_0-logloss:0.57391
# [2]	validation_0-logloss:0.52956
# [3]	validation_0-logloss:0.49115
# [4]	validation_0-logloss:0.45975
# [5]	validation_0-logloss:0.43207
# [6]	validation_0-logloss:0.40761
# [7]	validation_0-logloss:0.38697
# [8]	validation_0-logloss:0.36985
# [9]	validation_0-logloss:0.35383
# [10]	validation_0-logloss:0.33891
# [11]	validation_0-logloss:0.32649
# [12]	validation_0-logloss:0.31510
# [13]	validation_0-logloss:0.30542
# [14]	validation_0-logloss:0.29736
# [15]	validation_0-logloss:0.28943
# [16]	validation_0-logloss:0.28157
# [17]	validation_0-logloss:0.27563
# [18]	validation_0-logloss:0.26952
# [19]	validation_0-logloss:0.26414
# [20]	validation_0-logloss:0.25965
# [21]	validation_0-logloss:0.25609
# [22]	validation_0-logloss:0.25135
# [23]	validation_0-logloss:0.24760
# [24]	validation_0-logloss:0.24424
# [25]	validation_0-logloss:0.24155
# [26]	validation_0-logloss:0.23799
# [27]	validation_0-logloss:0.23502
# [28]	validation_0-logloss:0.23306
# [29]	validation_0-logloss:0.23086
# [30]	validation_0-logloss:0.22806
# [31]	validation_0-logloss:0.22553
# [32]	validation_0-logloss:0.22364
# [33]	validation_0-logloss:0.22176
# [34]	validation_0-logloss:0.22006
# [35]	validation_0-logloss:0.21776
# [36]	validation_0-logloss:0.21601
# [37]	validation_0-logloss:0.21424
# [38]	validation_0-logloss:0.21308
# [39]	validation_0-logloss:0.21186
# [40]	validation_0-logloss:0.21073
# [41]	validation_0-logloss:0.20963
# [42]	validation_0-logloss:0.20816
# [43]	validation_0-logloss:0.20722
# [44]	validation_0-logloss:0.20618
# [45]	validation_0-logloss:0.20544
# [46]	validation_0-logloss:0.20469
# [47]	validation_0-logloss:0.20369
# [48]	validation_0-logloss:0.20258
# [49]	validation_0-logloss:0.20178
# [50]	validation_0-logloss:0.20099
# [51]	validation_0-logloss:0.20036
# [52]	validation_0-logloss:0.19961
# [53]	validation_0-logloss:0.19851
# [54]	validation_0-logloss:0.19797
# [55]	validation_0-logloss:0.19744
# [56]	validation_0-logloss:0.19663
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [57]	validation_0-logloss:0.19597
# [58]	validation_0-logloss:0.19534
# [59]	validation_0-logloss:0.19451
# [60]	validation_0-logloss:0.19408
# [61]	validation_0-logloss:0.19364
# [62]	validation_0-logloss:0.19292
# [63]	validation_0-logloss:0.19237
# [64]	validation_0-logloss:0.19188
# [65]	validation_0-logloss:0.19124
# [66]	validation_0-logloss:0.19076
# [67]	validation_0-logloss:0.19056
# [68]	validation_0-logloss:0.19008
# [69]	validation_0-logloss:0.18981
# [70]	validation_0-logloss:0.18938
# [71]	validation_0-logloss:0.18916
# [72]	validation_0-logloss:0.18877
# [73]	validation_0-logloss:0.18845
# [74]	validation_0-logloss:0.18795
# [75]	validation_0-logloss:0.18755
# [76]	validation_0-logloss:0.18712
# [77]	validation_0-logloss:0.18686
# [78]	validation_0-logloss:0.18633
# [79]	validation_0-logloss:0.18578
# [80]	validation_0-logloss:0.18554
# [81]	validation_0-logloss:0.18519
# [82]	validation_0-logloss:0.18488
# [83]	validation_0-logloss:0.18436
# [84]	validation_0-logloss:0.18373
# [85]	validation_0-logloss:0.18340
# [86]	validation_0-logloss:0.18327
# [87]	validation_0-logloss:0.18254
# [88]	validation_0-logloss:0.18227
# [89]	validation_0-logloss:0.18203
# [90]	validation_0-logloss:0.18171
# [91]	validation_0-logloss:0.18132
# [92]	validation_0-logloss:0.18118
# [93]	validation_0-logloss:0.18084
# [94]	validation_0-logloss:0.18070
# [95]	validation_0-logloss:0.18025
# [96]	validation_0-logloss:0.17959
# [97]	validation_0-logloss:0.17914
# [98]	validation_0-logloss:0.17895
# [99]	validation_0-logloss:0.17884
# [100]	validation_0-logloss:0.17868
# [101]	validation_0-logloss:0.17843
# [102]	validation_0-logloss:0.17823
# [103]	validation_0-logloss:0.17811
# [104]	validation_0-logloss:0.17783
# [105]	validation_0-logloss:0.17753
# [106]	validation_0-logloss:0.17738
# [107]	validation_0-logloss:0.17721
# [108]	validation_0-logloss:0.17713
# [109]	validation_0-logloss:0.17696
# [110]	validation_0-logloss:0.17689
# [111]	validation_0-logloss:0.17685
# [112]	validation_0-logloss:0.17669
# [113]	validation_0-logloss:0.17675
# [114]	validation_0-logloss:0.17656
# [115]	validation_0-logloss:0.17659
# [116]	validation_0-logloss:0.17643
# [117]	validation_0-logloss:0.17629
# [118]	validation_0-logloss:0.17596
# [119]	validation_0-logloss:0.17589
# [120]	validation_0-logloss:0.17543
# [121]	validation_0-logloss:0.17522
# [122]	validation_0-logloss:0.17516
# [123]	validation_0-logloss:0.17513
# [124]	validation_0-logloss:0.17513
# [125]	validation_0-logloss:0.17500
# [126]	validation_0-logloss:0.17490
# [127]	validation_0-logloss:0.17497
# [128]	validation_0-logloss:0.17483
# [129]	validation_0-logloss:0.17466
# [130]	validation_0-logloss:0.17456
# [131]	validation_0-logloss:0.17416
# [132]	validation_0-logloss:0.17378
# [133]	validation_0-logloss:0.17388
# [134]	validation_0-logloss:0.17385
# [135]	validation_0-logloss:0.17365
# [136]	validation_0-logloss:0.17360
# [137]	validation_0-logloss:0.17355
# [138]	validation_0-logloss:0.17355
# [139]	validation_0-logloss:0.17306
# [140]	validation_0-logloss:0.17297
# [141]	validation_0-logloss:0.17281
# [142]	validation_0-logloss:0.17237
# [143]	validation_0-logloss:0.17241
# [144]	validation_0-logloss:0.17203
# [145]	validation_0-logloss:0.17195
# [146]	validation_0-logloss:0.17194
# [147]	validation_0-logloss:0.17189
# [148]	validation_0-logloss:0.17180
# [149]	validation_0-logloss:0.17151
# [150]	validation_0-logloss:0.17118
# [151]	validation_0-logloss:0.17103
# [152]	validation_0-logloss:0.17084
# [153]	validation_0-logloss:0.17054
# [154]	validation_0-logloss:0.17059
# [155]	validation_0-logloss:0.17051
# [156]	validation_0-logloss:0.17050
# [157]	validation_0-logloss:0.17048
# [158]	validation_0-logloss:0.17003
# [159]	validation_0-logloss:0.16981
# [160]	validation_0-logloss:0.16966
# [161]	validation_0-logloss:0.16964
# [162]	validation_0-logloss:0.16958
# [163]	validation_0-logloss:0.16953
# [164]	validation_0-logloss:0.16944
# [165]	validation_0-logloss:0.16938
# [166]	validation_0-logloss:0.16915
# [167]	validation_0-logloss:0.16905
# [168]	validation_0-logloss:0.16891
# [169]	validation_0-logloss:0.16876
# [170]	validation_0-logloss:0.16872
# [171]	validation_0-logloss:0.16870
# [172]	validation_0-logloss:0.16865
# [173]	validation_0-logloss:0.16845
# [174]	validation_0-logloss:0.16822
# [175]	validation_0-logloss:0.16820
# [176]	validation_0-logloss:0.16810
# [177]	validation_0-logloss:0.16805
# [178]	validation_0-logloss:0.16800
# [179]	validation_0-logloss:0.16797
# [180]	validation_0-logloss:0.16782
# [181]	validation_0-logloss:0.16780
# [182]	validation_0-logloss:0.16766
# [183]	validation_0-logloss:0.16761
# [184]	validation_0-logloss:0.16763
# [185]	validation_0-logloss:0.16762
# [186]	validation_0-logloss:0.16758
# [187]	validation_0-logloss:0.16736
# [188]	validation_0-logloss:0.16726
# [189]	validation_0-logloss:0.16714
# [190]	validation_0-logloss:0.16707
# [191]	validation_0-logloss:0.16708
# [192]	validation_0-logloss:0.16699
# [193]	validation_0-logloss:0.16703
# [194]	validation_0-logloss:0.16726
# [195]	validation_0-logloss:0.16712
# [196]	validation_0-logloss:0.16698
# [197]	validation_0-logloss:0.16679
# [198]	validation_0-logloss:0.16680
# [199]	validation_0-logloss:0.16679
# [200]	validation_0-logloss:0.16665
# [201]	validation_0-logloss:0.16663
# [202]	validation_0-logloss:0.16667
# [203]	validation_0-logloss:0.16645
# [204]	validation_0-logloss:0.16648
# [205]	validation_0-logloss:0.16634
# [206]	validation_0-logloss:0.16633
# [207]	validation_0-logloss:0.16637
# [208]	validation_0-logloss:0.16626
# [209]	validation_0-logloss:0.16616
# [210]	validation_0-logloss:0.16613
# [211]	validation_0-logloss:0.16602
# [212]	validation_0-logloss:0.16603
# [213]	validation_0-logloss:0.16597
# [214]	validation_0-logloss:0.16593
# [215]	validation_0-logloss:0.16579
# [216]	validation_0-logloss:0.16571
# [217]	validation_0-logloss:0.16574
# [218]	validation_0-logloss:0.16573
# [219]	validation_0-logloss:0.16573
# [220]	validation_0-logloss:0.16573
# [221]	validation_0-logloss:0.16570
# [222]	validation_0-logloss:0.16542
# [223]	validation_0-logloss:0.16491
# [224]	validation_0-logloss:0.16472
# [225]	validation_0-logloss:0.16456
# [226]	validation_0-logloss:0.16439
# [227]	validation_0-logloss:0.16434
# [228]	validation_0-logloss:0.16427
# [229]	validation_0-logloss:0.16417
# [230]	validation_0-logloss:0.16415
# [231]	validation_0-logloss:0.16408
# [232]	validation_0-logloss:0.16409
# [233]	validation_0-logloss:0.16378
# [234]	validation_0-logloss:0.16343
# [235]	validation_0-logloss:0.16316
# [236]	validation_0-logloss:0.16309
# [237]	validation_0-logloss:0.16312
# [238]	validation_0-logloss:0.16317
# [239]	validation_0-logloss:0.16323
# [240]	validation_0-logloss:0.16315
# [241]	validation_0-logloss:0.16315
# [242]	validation_0-logloss:0.16304
# [243]	validation_0-logloss:0.16296
# [244]	validation_0-logloss:0.16285
# [245]	validation_0-logloss:0.16270
# [246]	validation_0-logloss:0.16269
# [247]	validation_0-logloss:0.16256
# [248]	validation_0-logloss:0.16259
# [249]	validation_0-logloss:0.16259
# [250]	validation_0-logloss:0.16253
# [251]	validation_0-logloss:0.16255
# [252]	validation_0-logloss:0.16250
# [253]	validation_0-logloss:0.16256
# [254]	validation_0-logloss:0.16255
# [255]	validation_0-logloss:0.16259
# [256]	validation_0-logloss:0.16259
# [257]	validation_0-logloss:0.16250
# [258]	validation_0-logloss:0.16240
# [259]	validation_0-logloss:0.16240
# [260]	validation_0-logloss:0.16239
# [261]	validation_0-logloss:0.16238
# [262]	validation_0-logloss:0.16238
# [263]	validation_0-logloss:0.16233
# [264]	validation_0-logloss:0.16214
# [265]	validation_0-logloss:0.16217
# [266]	validation_0-logloss:0.16230
# [267]	validation_0-logloss:0.16234
# [268]	validation_0-logloss:0.16236
# [269]	validation_0-logloss:0.16246
# [270]	validation_0-logloss:0.16237
# [271]	validation_0-logloss:0.16237
# [272]	validation_0-logloss:0.16209
# [273]	validation_0-logloss:0.16207
# [274]	validation_0-logloss:0.16195
# [275]	validation_0-logloss:0.16198
# [276]	validation_0-logloss:0.16198
# [277]	validation_0-logloss:0.16189
# [278]	validation_0-logloss:0.16187
# [279]	validation_0-logloss:0.16194
# [280]	validation_0-logloss:0.16199
# [281]	validation_0-logloss:0.16195
# [282]	validation_0-logloss:0.16174
# [283]	validation_0-logloss:0.16175
# [284]	validation_0-logloss:0.16166
# [285]	validation_0-logloss:0.16155
# [286]	validation_0-logloss:0.16155
# [287]	validation_0-logloss:0.16154
# [288]	validation_0-logloss:0.16161
# [289]	validation_0-logloss:0.16164
# [290]	validation_0-logloss:0.16165
# [291]	validation_0-logloss:0.16170
# [292]	validation_0-logloss:0.16159
# [293]	validation_0-logloss:0.16171
# [294]	validation_0-logloss:0.16157
# [295]	validation_0-logloss:0.16118
# [296]	validation_0-logloss:0.16111
# [297]	validation_0-logloss:0.16097
# [298]	validation_0-logloss:0.16099
# [299]	validation_0-logloss:0.16090
# [300]	validation_0-logloss:0.16061
# [301]	validation_0-logloss:0.16066
# [302]	validation_0-logloss:0.16053
# [303]	validation_0-logloss:0.16036
# [304]	validation_0-logloss:0.16023
# [305]	validation_0-logloss:0.16024
# [306]	validation_0-logloss:0.16021
# [307]	validation_0-logloss:0.16006
# [308]	validation_0-logloss:0.15996
# [309]	validation_0-logloss:0.15991
# [310]	validation_0-logloss:0.15993
# [311]	validation_0-logloss:0.15992
# [312]	validation_0-logloss:0.15992
# [313]	validation_0-logloss:0.15993
# [314]	validation_0-logloss:0.16000
# [315]	validation_0-logloss:0.15995
# [316]	validation_0-logloss:0.15995
# [317]	validation_0-logloss:0.15976
# [318]	validation_0-logloss:0.15978
# [319]	validation_0-logloss:0.15979
# [320]	validation_0-logloss:0.15966
# [321]	validation_0-logloss:0.15965
# [322]	validation_0-logloss:0.15960
# [323]	validation_0-logloss:0.15968
# [324]	validation_0-logloss:0.15973
# [325]	validation_0-logloss:0.15967
# [326]	validation_0-logloss:0.15958
# [327]	validation_0-logloss:0.15958
# [328]	validation_0-logloss:0.15959
# [329]	validation_0-logloss:0.15945
# [330]	validation_0-logloss:0.15952
# [331]	validation_0-logloss:0.15957
# [332]	validation_0-logloss:0.15957
# [333]	validation_0-logloss:0.15955
# [334]	validation_0-logloss:0.15942
# [335]	validation_0-logloss:0.15937
# [336]	validation_0-logloss:0.15927
# [337]	validation_0-logloss:0.15922
# [338]	validation_0-logloss:0.15918
# [339]	validation_0-logloss:0.15897
# [340]	validation_0-logloss:0.15896
# [341]	validation_0-logloss:0.15901
# [342]	validation_0-logloss:0.15898
# [343]	validation_0-logloss:0.15890
# [344]	validation_0-logloss:0.15882
# [345]	validation_0-logloss:0.15882
# [346]	validation_0-logloss:0.15889
# [347]	validation_0-logloss:0.15881
# [348]	validation_0-logloss:0.15893
# [349]	validation_0-logloss:0.15890
# [350]	validation_0-logloss:0.15892
# [351]	validation_0-logloss:0.15880
# [352]	validation_0-logloss:0.15886
# [353]	validation_0-logloss:0.15887
# [354]	validation_0-logloss:0.15898
# [355]	validation_0-logloss:0.15895
# [356]	validation_0-logloss:0.15890
# [357]	validation_0-logloss:0.15888
# [358]	validation_0-logloss:0.15880
# [359]	validation_0-logloss:0.15851
# [360]	validation_0-logloss:0.15863
# [361]	validation_0-logloss:0.15864
# [362]	validation_0-logloss:0.15863
# [363]	validation_0-logloss:0.15874
# [364]	validation_0-logloss:0.15846
# [365]	validation_0-logloss:0.15837
# [366]	validation_0-logloss:0.15835
# [367]	validation_0-logloss:0.15836
# [368]	validation_0-logloss:0.15850
# [369]	validation_0-logloss:0.15840
# [370]	validation_0-logloss:0.15835
# [371]	validation_0-logloss:0.15836
# [372]	validation_0-logloss:0.15839
# [373]	validation_0-logloss:0.15836
# [374]	validation_0-logloss:0.15843
# [375]	validation_0-logloss:0.15842
# [376]	validation_0-logloss:0.15818
# [377]	validation_0-logloss:0.15837
# [378]	validation_0-logloss:0.15837
# [379]	validation_0-logloss:0.15840
# [380]	validation_0-logloss:0.15848
# [381]	validation_0-logloss:0.15853
# [382]	validation_0-logloss:0.15859
# [383]	validation_0-logloss:0.15853
# [384]	validation_0-logloss:0.15852
# [385]	validation_0-logloss:0.15859
# [386]	validation_0-logloss:0.15867
# [387]	validation_0-logloss:0.15856
# [388]	validation_0-logloss:0.15860
# [389]	validation_0-logloss:0.15871
# [390]	validation_0-logloss:0.15864
# [391]	validation_0-logloss:0.15856
# [392]	validation_0-logloss:0.15844
# [393]	validation_0-logloss:0.15845
# [394]	validation_0-logloss:0.15843
# [395]	validation_0-logloss:0.15854
# [396]	validation_0-logloss:0.15843
# [397]	validation_0-logloss:0.15842
# [398]	validation_0-logloss:0.15847
# [399]	validation_0-logloss:0.15853
# 오차행렬
# [[1669   32]
#  [  79  246]]
# 정확도:0.9452, 정밀도:0.8849, 재현율:0.7569, F1:0.8159, AUC:0.9618

# %%
# 사이킷런 래퍼 XGBoost 클래스인 XGBClassifier 임포트
from xgboost import XGBClassifier

xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3)
evals =[(X_test, y_test)]
xgb_wrapper.fit(X_train, y_train, early_stopping_rounds=10, eval_metric="logloss",
               eval_set=evals, verbose=True)
ws10_preds = xgb_wrapper.predict(X_test)
ws10_pred_proba = xgb_wrapper.predict_proba(X_test)[:,1]

get_clf_eval(y_test, ws10_preds, ws10_pred_proba)
# Out:
# [0]	validation_0-logloss:0.62768
# [1]	validation_0-logloss:0.57391
# [2]	validation_0-logloss:0.52956
# [3]	validation_0-logloss:0.49115
# [4]	validation_0-logloss:0.45975
# [5]	validation_0-logloss:0.43207
# [6]	validation_0-logloss:0.40761
# [7]	validation_0-logloss:0.38697
# [8]	validation_0-logloss:0.36985
# [9]	validation_0-logloss:0.35383
# [10]	validation_0-logloss:0.33891
# [11]	validation_0-logloss:0.32649
# [12]	validation_0-logloss:0.31510
# [13]	validation_0-logloss:0.30542
# [14]	validation_0-logloss:0.29736
# [15]	validation_0-logloss:0.28943
# [16]	validation_0-logloss:0.28157
# [17]	validation_0-logloss:0.27563
# [18]	validation_0-logloss:0.26952
# [19]	validation_0-logloss:0.26414
# [20]	validation_0-logloss:0.25965
# [21]	validation_0-logloss:0.25609
# [22]	validation_0-logloss:0.25135
# [23]	validation_0-logloss:0.24760
# [24]	validation_0-logloss:0.24424
# [25]	validation_0-logloss:0.24155
# [26]	validation_0-logloss:0.23799
# [27]	validation_0-logloss:0.23502
# [28]	validation_0-logloss:0.23306
# [29]	validation_0-logloss:0.23086
# [30]	validation_0-logloss:0.22806
# [31]	validation_0-logloss:0.22553
# [32]	validation_0-logloss:0.22364
# [33]	validation_0-logloss:0.22176
# [34]	validation_0-logloss:0.22006
# [35]	validation_0-logloss:0.21776
# [36]	validation_0-logloss:0.21601
# [37]	validation_0-logloss:0.21424
# [38]	validation_0-logloss:0.21308
# [39]	validation_0-logloss:0.21186
# [40]	validation_0-logloss:0.21073
# [41]	validation_0-logloss:0.20963
# [42]	validation_0-logloss:0.20816
# [43]	validation_0-logloss:0.20722
# [44]	validation_0-logloss:0.20618
# [45]	validation_0-logloss:0.20544
# [46]	validation_0-logloss:0.20469
# [47]	validation_0-logloss:0.20369
# [48]	validation_0-logloss:0.20258
# [49]	validation_0-logloss:0.20178
# [50]	validation_0-logloss:0.20099
# [51]	validation_0-logloss:0.20036
# [52]	validation_0-logloss:0.19961
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [53]	validation_0-logloss:0.19851
# [54]	validation_0-logloss:0.19797
# [55]	validation_0-logloss:0.19744
# [56]	validation_0-logloss:0.19663
# [57]	validation_0-logloss:0.19597
# [58]	validation_0-logloss:0.19534
# [59]	validation_0-logloss:0.19451
# [60]	validation_0-logloss:0.19408
# [61]	validation_0-logloss:0.19364
# [62]	validation_0-logloss:0.19292
# [63]	validation_0-logloss:0.19237
# [64]	validation_0-logloss:0.19188
# [65]	validation_0-logloss:0.19124
# [66]	validation_0-logloss:0.19076
# [67]	validation_0-logloss:0.19056
# [68]	validation_0-logloss:0.19008
# [69]	validation_0-logloss:0.18981
# [70]	validation_0-logloss:0.18938
# [71]	validation_0-logloss:0.18916
# [72]	validation_0-logloss:0.18877
# [73]	validation_0-logloss:0.18845
# [74]	validation_0-logloss:0.18795
# [75]	validation_0-logloss:0.18755
# [76]	validation_0-logloss:0.18712
# [77]	validation_0-logloss:0.18686
# [78]	validation_0-logloss:0.18633
# [79]	validation_0-logloss:0.18578
# [80]	validation_0-logloss:0.18554
# [81]	validation_0-logloss:0.18519
# [82]	validation_0-logloss:0.18488
# [83]	validation_0-logloss:0.18436
# [84]	validation_0-logloss:0.18373
# [85]	validation_0-logloss:0.18340
# [86]	validation_0-logloss:0.18327
# [87]	validation_0-logloss:0.18254
# [88]	validation_0-logloss:0.18227
# [89]	validation_0-logloss:0.18203
# [90]	validation_0-logloss:0.18171
# [91]	validation_0-logloss:0.18132
# [92]	validation_0-logloss:0.18118
# [93]	validation_0-logloss:0.18084
# [94]	validation_0-logloss:0.18070
# [95]	validation_0-logloss:0.18025
# [96]	validation_0-logloss:0.17959
# [97]	validation_0-logloss:0.17914
# [98]	validation_0-logloss:0.17895
# [99]	validation_0-logloss:0.17884
# [100]	validation_0-logloss:0.17868
# [101]	validation_0-logloss:0.17843
# [102]	validation_0-logloss:0.17823
# [103]	validation_0-logloss:0.17811
# [104]	validation_0-logloss:0.17783
# [105]	validation_0-logloss:0.17753
# [106]	validation_0-logloss:0.17738
# [107]	validation_0-logloss:0.17721
# [108]	validation_0-logloss:0.17713
# [109]	validation_0-logloss:0.17696
# [110]	validation_0-logloss:0.17689
# [111]	validation_0-logloss:0.17685
# [112]	validation_0-logloss:0.17669
# [113]	validation_0-logloss:0.17675
# [114]	validation_0-logloss:0.17656
# [115]	validation_0-logloss:0.17659
# [116]	validation_0-logloss:0.17643
# [117]	validation_0-logloss:0.17629
# [118]	validation_0-logloss:0.17596
# [119]	validation_0-logloss:0.17589
# [120]	validation_0-logloss:0.17543
# [121]	validation_0-logloss:0.17522
# [122]	validation_0-logloss:0.17516
# [123]	validation_0-logloss:0.17513
# [124]	validation_0-logloss:0.17513
# [125]	validation_0-logloss:0.17500
# [126]	validation_0-logloss:0.17490
# [127]	validation_0-logloss:0.17497
# [128]	validation_0-logloss:0.17483
# [129]	validation_0-logloss:0.17466
# [130]	validation_0-logloss:0.17456
# [131]	validation_0-logloss:0.17416
# [132]	validation_0-logloss:0.17378
# [133]	validation_0-logloss:0.17388
# [134]	validation_0-logloss:0.17385
# [135]	validation_0-logloss:0.17365
# [136]	validation_0-logloss:0.17360
# [137]	validation_0-logloss:0.17355
# [138]	validation_0-logloss:0.17355
# [139]	validation_0-logloss:0.17306
# [140]	validation_0-logloss:0.17297
# [141]	validation_0-logloss:0.17281
# [142]	validation_0-logloss:0.17237
# [143]	validation_0-logloss:0.17241
# [144]	validation_0-logloss:0.17203
# [145]	validation_0-logloss:0.17195
# [146]	validation_0-logloss:0.17194
# [147]	validation_0-logloss:0.17189
# [148]	validation_0-logloss:0.17180
# [149]	validation_0-logloss:0.17151
# [150]	validation_0-logloss:0.17118
# [151]	validation_0-logloss:0.17103
# [152]	validation_0-logloss:0.17084
# [153]	validation_0-logloss:0.17054
# [154]	validation_0-logloss:0.17059
# [155]	validation_0-logloss:0.17051
# [156]	validation_0-logloss:0.17050
# [157]	validation_0-logloss:0.17048
# [158]	validation_0-logloss:0.17003
# [159]	validation_0-logloss:0.16981
# [160]	validation_0-logloss:0.16966
# [161]	validation_0-logloss:0.16964
# [162]	validation_0-logloss:0.16958
# [163]	validation_0-logloss:0.16953
# [164]	validation_0-logloss:0.16944
# [165]	validation_0-logloss:0.16938
# [166]	validation_0-logloss:0.16915
# [167]	validation_0-logloss:0.16905
# [168]	validation_0-logloss:0.16891
# [169]	validation_0-logloss:0.16876
# [170]	validation_0-logloss:0.16872
# [171]	validation_0-logloss:0.16870
# [172]	validation_0-logloss:0.16865
# [173]	validation_0-logloss:0.16845
# [174]	validation_0-logloss:0.16822
# [175]	validation_0-logloss:0.16820
# [176]	validation_0-logloss:0.16810
# [177]	validation_0-logloss:0.16805
# [178]	validation_0-logloss:0.16800
# [179]	validation_0-logloss:0.16797
# [180]	validation_0-logloss:0.16782
# [181]	validation_0-logloss:0.16780
# [182]	validation_0-logloss:0.16766
# [183]	validation_0-logloss:0.16761
# [184]	validation_0-logloss:0.16763
# [185]	validation_0-logloss:0.16762
# [186]	validation_0-logloss:0.16758
# [187]	validation_0-logloss:0.16736
# [188]	validation_0-logloss:0.16726
# [189]	validation_0-logloss:0.16714
# [190]	validation_0-logloss:0.16707
# [191]	validation_0-logloss:0.16708
# [192]	validation_0-logloss:0.16699
# [193]	validation_0-logloss:0.16703
# [194]	validation_0-logloss:0.16726
# [195]	validation_0-logloss:0.16712
# [196]	validation_0-logloss:0.16698
# [197]	validation_0-logloss:0.16679
# [198]	validation_0-logloss:0.16680
# [199]	validation_0-logloss:0.16679
# [200]	validation_0-logloss:0.16665
# [201]	validation_0-logloss:0.16663
# [202]	validation_0-logloss:0.16667
# [203]	validation_0-logloss:0.16645
# [204]	validation_0-logloss:0.16648
# [205]	validation_0-logloss:0.16634
# [206]	validation_0-logloss:0.16633
# [207]	validation_0-logloss:0.16637
# [208]	validation_0-logloss:0.16626
# [209]	validation_0-logloss:0.16616
# [210]	validation_0-logloss:0.16613
# [211]	validation_0-logloss:0.16602
# [212]	validation_0-logloss:0.16603
# [213]	validation_0-logloss:0.16597
# [214]	validation_0-logloss:0.16593
# [215]	validation_0-logloss:0.16579
# [216]	validation_0-logloss:0.16571
# [217]	validation_0-logloss:0.16574
# [218]	validation_0-logloss:0.16573
# [219]	validation_0-logloss:0.16573
# [220]	validation_0-logloss:0.16573
# [221]	validation_0-logloss:0.16570
# [222]	validation_0-logloss:0.16542
# [223]	validation_0-logloss:0.16491
# [224]	validation_0-logloss:0.16472
# [225]	validation_0-logloss:0.16456
# [226]	validation_0-logloss:0.16439
# [227]	validation_0-logloss:0.16434
# [228]	validation_0-logloss:0.16427
# [229]	validation_0-logloss:0.16417
# [230]	validation_0-logloss:0.16415
# [231]	validation_0-logloss:0.16408
# [232]	validation_0-logloss:0.16409
# [233]	validation_0-logloss:0.16378
# [234]	validation_0-logloss:0.16343
# [235]	validation_0-logloss:0.16316
# [236]	validation_0-logloss:0.16309
# [237]	validation_0-logloss:0.16312
# [238]	validation_0-logloss:0.16317
# [239]	validation_0-logloss:0.16323
# [240]	validation_0-logloss:0.16315
# [241]	validation_0-logloss:0.16315
# [242]	validation_0-logloss:0.16304
# [243]	validation_0-logloss:0.16296
# [244]	validation_0-logloss:0.16285
# [245]	validation_0-logloss:0.16270
# [246]	validation_0-logloss:0.16269
# [247]	validation_0-logloss:0.16256
# [248]	validation_0-logloss:0.16259
# [249]	validation_0-logloss:0.16259
# [250]	validation_0-logloss:0.16253
# [251]	validation_0-logloss:0.16255
# [252]	validation_0-logloss:0.16250
# [253]	validation_0-logloss:0.16256
# [254]	validation_0-logloss:0.16255
# [255]	validation_0-logloss:0.16259
# [256]	validation_0-logloss:0.16259
# [257]	validation_0-logloss:0.16250
# [258]	validation_0-logloss:0.16240
# [259]	validation_0-logloss:0.16240
# [260]	validation_0-logloss:0.16239
# [261]	validation_0-logloss:0.16238
# [262]	validation_0-logloss:0.16238
# [263]	validation_0-logloss:0.16233
# [264]	validation_0-logloss:0.16214
# [265]	validation_0-logloss:0.16217
# [266]	validation_0-logloss:0.16230
# [267]	validation_0-logloss:0.16234
# [268]	validation_0-logloss:0.16236
# [269]	validation_0-logloss:0.16246
# [270]	validation_0-logloss:0.16237
# [271]	validation_0-logloss:0.16237
# [272]	validation_0-logloss:0.16209
# [273]	validation_0-logloss:0.16207
# [274]	validation_0-logloss:0.16195
# [275]	validation_0-logloss:0.16198
# [276]	validation_0-logloss:0.16198
# [277]	validation_0-logloss:0.16189
# [278]	validation_0-logloss:0.16187
# [279]	validation_0-logloss:0.16194
# [280]	validation_0-logloss:0.16199
# [281]	validation_0-logloss:0.16195
# [282]	validation_0-logloss:0.16174
# [283]	validation_0-logloss:0.16175
# [284]	validation_0-logloss:0.16166
# [285]	validation_0-logloss:0.16155
# [286]	validation_0-logloss:0.16155
# [287]	validation_0-logloss:0.16154
# [288]	validation_0-logloss:0.16161
# [289]	validation_0-logloss:0.16164
# [290]	validation_0-logloss:0.16165
# [291]	validation_0-logloss:0.16170
# [292]	validation_0-logloss:0.16159
# [293]	validation_0-logloss:0.16171
# [294]	validation_0-logloss:0.16157
# [295]	validation_0-logloss:0.16118
# [296]	validation_0-logloss:0.16111
# [297]	validation_0-logloss:0.16097
# [298]	validation_0-logloss:0.16099
# [299]	validation_0-logloss:0.16090
# [300]	validation_0-logloss:0.16061
# [301]	validation_0-logloss:0.16066
# [302]	validation_0-logloss:0.16053
# [303]	validation_0-logloss:0.16036
# [304]	validation_0-logloss:0.16023
# [305]	validation_0-logloss:0.16024
# [306]	validation_0-logloss:0.16021
# [307]	validation_0-logloss:0.16006
# [308]	validation_0-logloss:0.15996
# [309]	validation_0-logloss:0.15991
# [310]	validation_0-logloss:0.15993
# [311]	validation_0-logloss:0.15992
# [312]	validation_0-logloss:0.15992
# [313]	validation_0-logloss:0.15993
# [314]	validation_0-logloss:0.16000
# [315]	validation_0-logloss:0.15995
# [316]	validation_0-logloss:0.15995
# [317]	validation_0-logloss:0.15976
# [318]	validation_0-logloss:0.15978
# [319]	validation_0-logloss:0.15979
# [320]	validation_0-logloss:0.15966
# [321]	validation_0-logloss:0.15965
# [322]	validation_0-logloss:0.15960
# [323]	validation_0-logloss:0.15968
# [324]	validation_0-logloss:0.15973
# [325]	validation_0-logloss:0.15967
# [326]	validation_0-logloss:0.15958
# [327]	validation_0-logloss:0.15958
# [328]	validation_0-logloss:0.15959
# [329]	validation_0-logloss:0.15945
# [330]	validation_0-logloss:0.15952
# [331]	validation_0-logloss:0.15957
# [332]	validation_0-logloss:0.15957
# [333]	validation_0-logloss:0.15955
# [334]	validation_0-logloss:0.15942
# [335]	validation_0-logloss:0.15937
# [336]	validation_0-logloss:0.15927
# [337]	validation_0-logloss:0.15922
# [338]	validation_0-logloss:0.15918
# [339]	validation_0-logloss:0.15897
# [340]	validation_0-logloss:0.15896
# [341]	validation_0-logloss:0.15901
# [342]	validation_0-logloss:0.15898
# [343]	validation_0-logloss:0.15890
# [344]	validation_0-logloss:0.15882
# [345]	validation_0-logloss:0.15882
# [346]	validation_0-logloss:0.15889
# [347]	validation_0-logloss:0.15881
# [348]	validation_0-logloss:0.15893
# [349]	validation_0-logloss:0.15890
# [350]	validation_0-logloss:0.15892
# [351]	validation_0-logloss:0.15880
# [352]	validation_0-logloss:0.15886
# [353]	validation_0-logloss:0.15887
# [354]	validation_0-logloss:0.15898
# [355]	validation_0-logloss:0.15895
# [356]	validation_0-logloss:0.15890
# [357]	validation_0-logloss:0.15888
# [358]	validation_0-logloss:0.15880
# [359]	validation_0-logloss:0.15851
# [360]	validation_0-logloss:0.15863
# [361]	validation_0-logloss:0.15864
# [362]	validation_0-logloss:0.15863
# [363]	validation_0-logloss:0.15874
# [364]	validation_0-logloss:0.15846
# [365]	validation_0-logloss:0.15837
# [366]	validation_0-logloss:0.15835
# [367]	validation_0-logloss:0.15836
# [368]	validation_0-logloss:0.15850
# [369]	validation_0-logloss:0.15840
# [370]	validation_0-logloss:0.15835
# [371]	validation_0-logloss:0.15836
# [372]	validation_0-logloss:0.15839
# [373]	validation_0-logloss:0.15836
# [374]	validation_0-logloss:0.15843
# [375]	validation_0-logloss:0.15842
# [376]	validation_0-logloss:0.15818
# [377]	validation_0-logloss:0.15837
# [378]	validation_0-logloss:0.15837
# [379]	validation_0-logloss:0.15840
# [380]	validation_0-logloss:0.15848
# [381]	validation_0-logloss:0.15853
# [382]	validation_0-logloss:0.15859
# [383]	validation_0-logloss:0.15853
# [384]	validation_0-logloss:0.15852
# [385]	validation_0-logloss:0.15859
# [386]	validation_0-logloss:0.15867
# 오차행렬
# [[1669   32]
#  [  79  246]]
# 정확도:0.9452, 정밀도:0.8849, 재현율:0.7569, F1:0.8159, AUC:0.9618

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10,12))
# 사이킷런 Wrapper 클래스를 입력해도 무방
plot_importance(xgb_wrapper, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# **SMOTE 오버샘플링 적용 후 모델 학습/예측/평가**

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=0)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)
print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트', X_train.shape, y_train.shape)
print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트', X_train_over.shape, y_train_over.shape)
# Out:
# SMOTE 적용 전 학습용 피처/레이블 데이터 세트 (8101, 15) (8101,)
# SMOTE 적용 전 학습용 피처/레이블 데이터 세트 (13598, 15) (13598,)

# %%
from sklearn.tree import DecisionTreeClassifier # 의사결정 나무
from sklearn.ensemble import RandomForestClassifier # 랜덤 포레스트
from sklearn.linear_model import LogisticRegression # 로지스틱 회귀
from sklearn.neighbors import KNeighborsClassifier # k-최근접이웃

# 사이킷런 Classifier 클래스 생성
dt_clf = DecisionTreeClassifier(random_state=11)
rf_clf = RandomForestClassifier(random_state=11)
lr_clf = LogisticRegression()

# DecisionTreeClassifier 학습/예측/평가
dt_clf.fit(X_train_over, y_train_over)
dt_pred = dt_clf.predict(X_test)
dt_pred_proba = dt_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test, dt_pred, dt_pred_proba)

# RandomForestClassifier
rf_clf.fit(X_train_over, y_train_over)
rf_pred = rf_clf.predict(X_test)
rf_pred_proba = rf_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test.values, rf_pred, rf_pred_proba)

# LogistRegression
lr_clf.fit(X_train_over, y_train_over)
lr_pred = lr_clf.predict(X_test)
lr_pred_proba = lr_clf.predict_proba(X_test)[:,1]
get_clf_eval(y_test.values, lr_pred, lr_pred_proba)
# Out:
# 오차행렬
# [[1557  144]
#  [  89  236]]
# 정확도:0.8850, 정밀도:0.6211, 재현율:0.7262, F1:0.6695, AUC:0.8207
# 오차행렬
# [[1643   58]
#  [  75  250]]
# 정확도:0.9344, 정밀도:0.8117, 재현율:0.7692, F1:0.7899, AUC:0.9549
# 오차행렬
# [[1421  280]
#  [  81  244]]
# 정확도:0.8218, 정밀도:0.4656, 재현율:0.7508, F1:0.5748, AUC:0.8793
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# 사이킷런 래퍼 XGBoost 클래스인 XGBClassifier 임포트
from xgboost import XGBClassifier

xgb_wrapper = XGBClassifier(n_estimators=600, learning_rate=0.1, max_depth=3)
xgb_wrapper.fit(X_train_over, y_train_over)
w_preds = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:,1]

get_clf_eval(y_test, w_preds, w_pred_proba)
# Out:
# /Users/heejinkim/miniforge3/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:06:14] WARNING: /Users/ktietz/demo/mc3/conda-bld/xgboost-split_1628682908089/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 오차행렬
# [[1657   44]
#  [  69  256]]
# 정확도:0.9442, 정밀도:0.8533, 재현율:0.7877, F1:0.8192, AUC:0.9629

# %%
preds = w_preds  
pred_proba = w_pred_proba

# %%
from sklearn.preprocessing import Binarizer

binarizer = Binarizer(threshold=1.0)
from sklearn.preprocessing import Binarizer

binarizer = Binarizer(threshold=1.0)
from sklearn.metrics import accuracy_score, precision_score , recall_score , confusion_matrix

def get_clf_eval(y_test, pred) : 
    confusion = confusion_matrix(y_test, pred)  # 오차행렬
    accuracy = accuracy_score(y_test, pred)     # 정확도
    precision = precision_score(y_test, pred)    # 정밀도
    recall = recall_score(y_test, pred)         # 재현율
    
    print('오차행렬')
    print(confusion)
    print('정확도: {0:.3f}, 정밀도: {1:.3f}, 재현율: {2:.3f}'.format(accuracy, precision, recall))   
    
from sklearn.preprocessing import Binarizer

# Binarizer의 threshold 설정값. 분류 결정 임계값 = 0.5로 설정.  
c_threshold = 0.5

# predict_proba() 반환값이 [0확률, 1확률]로 반환 - positive 클래스 컬럼만 추출해서 Binarizer를 적용
pred_proba_1 = pred_proba.reshape(-1,1)

bina = Binarizer(threshold=c_threshold).fit(pred_proba_1)
custom_predict = bina.transform(pred_proba_1)

get_clf_eval(y_test,custom_predict)
# Out:
# 오차행렬
# [[1657   44]
#  [  69  256]]
# 정확도: 0.944, 정밀도: 0.853, 재현율: 0.788

# %%
pred_proba
# Out:
# array([9.98536825e-01, 1.00246705e-02, 9.85194856e-05, ...,
#        9.81516123e-01, 3.66510957e-01, 8.76743376e-01], dtype=float32)

# %% [markdown]
# **앙상블 학습**

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### 5 (2) 군집화

# %% [markdown]
# ### KMeans 클래스
# class sklearn.cluster.KMeans(n_cluster=2, init='k-means++', n_init=10, max_iter=3--. tol=0.0001,
#                             precompute_distances='auto',verbose=0,random_state=None,
#                             copy_x=True, n_jobs=1, algorithm='auto')

# %%
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, init='k-means++',max_iter=300,random_state=0)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
X["target"]=y
X["cluster"]=kmeans.labels_

# %%
df_result = X.groupby(['target','cluster'])['Customer_Age'].count()
print(df_result)
# Out:
# target  cluster
# 0       0          5833
#         1          2667
# 1       0          1162
#         1           465
# Name: Customer_Age, dtype: int64

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(X)

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('/Users/heejinkim/Desktop/hayul.png')
plt.imshow(img)
plt.show()
