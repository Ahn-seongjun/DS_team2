# %% [markdown]
# # 타이나닉 생존자 분석
# ### 머신러닝 기반 타이타닉 생존자 예측
# - 목적
# - 데이터 수집
# - 데이터 확인 및 시각화
# - 데이터 전처리 및 피쳐 엔지니어링
# - 모델링
# - 테스팅

# %% [markdown]
# ## 1. 목적
# 타이타닉 사고에서 어떤 종류의 사람이 살아남았는지 분석
# 생존자 분석을 위해 머신러닝 적용

# %% [markdown]
# ## 2. 데이터 수집
#
# 출처 : 케글 [kaggle](https://www.kaggle.com/c/titanic/data)

# %% [markdown]
# #### 데이터 읽어오기

# %%
import pandas as pd

train = pd.read_csv('./data/titanic/train.csv')
test = pd.read_csv('./data/titanic/test.csv')

# %% [markdown]
# #### 필요한 패키지 가져오기

# %%
import pandas as pd
import numpy as np
import seaborn as sns

#그래프 패키지 
import matplotlib.pyplot as plt 
# %matplotlib inline 
# 한글 문제 해결
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')# 한글 문제 해결
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')


# 동시 출력
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %% [markdown]
# ## 3. 데이터 확인 및 시각화

# %% [markdown]
# #### 데이터 확인

# %%
train.shape
train.head(80)
# Out:
# (891, 12)
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 75           76         0       3
# 76           77         0       3
# 77           78         0       3
# 78           79         1       2
# 79           80         1       3
#
#                                                  Name     Sex    Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.00      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                              Heikkinen, Miss. Laina  female  26.00      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 4                            Allen, Mr. William Henry    male  35.00      0
# ..                                                ...     ...    ...    ...
# 75                            Moen, Mr. Sigurd Hansen    male  25.00      0
# 76                                  Staneff, Mr. Ivan    male    NaN      0
# 77                           Moutal, Mr. Rahamin Haim    male    NaN      0
# 78                      Caldwell, Master. Alden Gates    male   0.83      0
# 79                           Dowdell, Miss. Elizabeth  female  30.00      0
#
#     Parch            Ticket     Fare  Cabin Embarked
# 0       0         A/5 21171   7.2500    NaN        S
# 1       0          PC 17599  71.2833    C85        C
# 2       0  STON/O2. 3101282   7.9250    NaN        S
# 3       0            113803  53.1000   C123        S
# 4       0            373450   8.0500    NaN        S
# ..    ...               ...      ...    ...      ...
# 75      0            348123   7.6500  F G73        S
# 76      0            349208   7.8958    NaN        S
# 77      0            374746   8.0500    NaN        S
# 78      2            248738  29.0000    NaN        S
# 79      0            364516  12.4750    NaN        S
#
# [80 rows x 12 columns]

# %% [markdown]
# ### Data Dictionary
# - Survived: 	0 = No, 1 = Yes
# - pclass: 	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# - sibsp:	# of siblings / spouses aboard the Titanic (같이 탑승한 형제자매 또는 배우자 인원수)
# - parch:	# of parents / children aboard the Titanic (같이 탑승한 부모님 또는 어린이 인원수)
# - ticket:	Ticket number
# - cabin:	Cabin number
# - embarked:	중간 정착 항구 C = Cherbourg, Q = Queenstown, S = Southampton

# %%
test.shape
test.head()
# Out:
# (418, 11)
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# #### 결측치 확인

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# #### 데이터 분석을 위한 시각화

# %%
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))
    plt.xticks(rotation=0)

# %%
bar_chart('Sex')

# %% [markdown]
# 생존자는 여자가 많다는 것을 확인

# %%
bar_chart('Pclass')

# %% [markdown]
# 3 class 승객이 더 많이 사망한 것을 확인 가능

# %%
bar_chart('SibSp')

# %% [markdown]
# 형제/자매 없이 혼자 탑승한 승객의 사망자 수가 앞도적으로 많음

# %%
bar_chart('Parch')

# %% [markdown]
# 부모/자녀와 함께 탑승한 사람보다 혼자 탑승한 승객의 사망자 수가 앞도적으로 많음

# %%
bar_chart('Embarked')

# %% [markdown]
# Southampton(사우스샘프턴)에서 탑승한 승객의 사망자 수가 많음

# %% [markdown]
# ## 4. 데이터 전처리 및 피쳐 엔지니어링
#
# - 데이터 전처리 작업진행
# - 머신러닝에 사용 가능할 수 있게 피쳐 수정

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 데이터 분석에 필요한 배경지식
# - 3 class 존재하는 뱃머리에 침몰이 시작
# - class 별 생존률이 다름

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ### Name
# - 이름에는 사람의 성별과 결혼 여부를 알 수 있는 정보를 포함
# - Name은 중요한 정보

# %% [markdown]
# #### train과 test에서 name 데이터 파싱작업 진행

# %% [markdown]
# **str.extract(' ([A-Za-z]+)\.', expand=False)**
# - str.extract(pat,flag,expand)
# - pat : 추출할 조건
# - flag : 영역
# - expand : True-column 단위, False-label 단위
# - ([A-Za-z]+)\. : 대문자로 시작해서 소문자로 끝나고 .(점) 있으면 추출 (성별, 결혼여부 파악)

# %%
train_test_data = [train, test] # 하나로 뭉쳐서 둘다 동시에 적요할려고
for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Mlle          2
# Col           2
# Sir           1
# Jonkheer      1
# Don           1
# Ms            1
# Countess      1
# Lady          1
# Mme           1
# Capt          1
# Name: Title, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Dona        1
# Dr          1
# Ms          1
# Name: Title, dtype: int64

# %% [markdown]
# #### Title map
# Mr : 0
# Miss : 1
# Mrs: 2
# Others: 3

# %%
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      2
# 4      0            373450   8.0500   NaN        S      0

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Title
# 0  34.5      0      0   330911   7.8292   NaN        Q      0
# 1  47.0      1      0   363272   7.0000   NaN        S      2
# 2  62.0      0      0   240276   9.6875   NaN        Q      0
# 3  27.0      0      0   315154   8.6625   NaN        S      0
# 4  22.0      1      1  3101298  12.2875   NaN        S      2

# %%
bar_chart('Title')

# %% [markdown]
# Miss : 1, Mrs: 2의 생존이 높은 것을 확인

# %%
# 이제는 불필요한 Name 컬럼 삭제
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      0
# 1          PC 17599  71.2833   C85        C      2
# 2  STON/O2. 3101282   7.9250   NaN        S      1
# 3            113803  53.1000  C123        S      2
# 4            373450   8.0500   NaN        S      0

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    male  34.5      0      0   330911   7.8292   NaN
# 1          893       3  female  47.0      1      0   363272   7.0000   NaN
# 2          894       2    male  62.0      0      0   240276   9.6875   NaN
# 3          895       3    male  27.0      0      0   315154   8.6625   NaN
# 4          896       3  female  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked  Title
# 0        Q      0
# 1        S      2
# 2        Q      0
# 3        S      0
# 4        S      2

# %% [markdown]
# ### Sex
#
# - male: 0 female: 1 변경

# %%
## 숫자로 성병 변경
sex_mapping = {"male": 0, "female": 1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
bar_chart('Sex')

# %% [markdown]
# ###  Age

# %% [markdown]
# #### 결측치 처리
# - name에서 추출한 Tilte 속성값을 기준으로 평균 나이로 처리
#
#
# Mr : 0, Miss : 1, Mrs: 2, Others: 3

# %%
train.head(100)
# Out:
#     PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  22.0      1      0         A/5 21171
# 1             2         1       1    1  38.0      1      0          PC 17599
# 2             3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  35.0      1      0            113803
# 4             5         0       3    0  35.0      0      0            373450
# ..          ...       ...     ...  ...   ...    ...    ...               ...
# 95           96         0       3    0   NaN      0      0            374910
# 96           97         0       1    0  71.0      0      0          PC 17754
# 97           98         1       1    0  23.0      0      1          PC 17759
# 98           99         1       2    1  34.0      0      1            231919
# 99          100         0       2    0  34.0      1      0            244367
#
#        Fare    Cabin Embarked  Title
# 0    7.2500      NaN        S      0
# 1   71.2833      C85        C      2
# 2    7.9250      NaN        S      1
# 3   53.1000     C123        S      2
# 4    8.0500      NaN        S      0
# ..      ...      ...      ...    ...
# 95   8.0500      NaN        S      0
# 96  34.6542       A5        C      0
# 97  63.3583  D10 D12        C      0
# 98  23.0000      NaN        S      2
# 99  26.0000      NaN        S      0
#
# [100 rows x 12 columns]

# %%
# fill missing age with median age for each title (Mr, Mrs, Miss, Others)
train["Age"].fillna(round(train["Age"].mean(),0), inplace=True)
test["Age"].fillna(round(test["Age"].mean(),0), inplace=True)

# %% [markdown]
# #### 물어볼것

# %%
## 문법 오류???
## 결측치가 변화지 않음

#train["Age"].fillna(train.groupby("Title")["Age"].transform("median"), inplace=True)
#test["Age"].fillna(test.groupby("Title")["Age"].transform("median"), inplace=True)

# %%
## 결측치 확인
train["Age"].isnull().sum()
test["Age"].isnull().sum()
# Out:
# 0
# 0

# %%
## 생존 여부를 비교하기 위한 그래프
# 0:사망 1:생존
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
 
plt.show()

# %%
## 20살까지
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(0, 20)
# Out:
# (0.0, 20.0)

# %%
## 20~30살
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(20, 30)
# Out:
# (20.0, 30.0)

# %%
## 30~40살
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(30, 40)
# Out:
# (30.0, 40.0)

# %%
## 40~60살
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(40, 60)
# Out:
# (40.0, 60.0)

# %%
## 40~60살
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(40, 60)
# Out:
# (40.0, 60.0)

# %%
## 60살 ~ 끝
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(60)
# Out:
# (60.0, 80.0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Title        891 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Sex          418 non-null    int64
#  3   Age          418 non-null    float64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Ticket       418 non-null    object
#  7   Fare         417 non-null    float64
#  8   Cabin        91 non-null     object
#  9   Embarked     418 non-null    object
#  10  Title        418 non-null    int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 36.0+ KB

# %% [markdown]
# ### Bin 사용
# - 연령대로 나누어서 비교

# %% [markdown]
# #### 나이 기준
# 어린이: 0  (15살 이하)
#
# 청소년: 1  (15살 ~ 30살)
#
# 청년: 2  (31살 ~ 40살)
#
# 중년: 3  (41살 ~ 60살)
#
# 노인: 4  (61살 ~)

# %%
for dataset in train_test_data:
    dataset.loc[dataset['Age'] <= 15, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 15) & (dataset['Age'] <= 30), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 30) & (dataset['Age'] <= 40), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 40) & (dataset['Age'] <= 60), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 60, 'Age'] = 4

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0

# %%
bar_chart('Age')

# %% [markdown]
# 청소년: 1 (15살 ~ 30살) 청년: 2 (31살 ~ 40살)의 생존률이 높음

# %% [markdown]
# ### 4.5 Embarked
# - 탑승지에 따른 생존여부

# %%
Pclass1 = train[train['Pclass']==1]['Embarked'].value_counts()
Pclass2 = train[train['Pclass']==2]['Embarked'].value_counts()
Pclass3 = train[train['Pclass']==3]['Embarked'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 결측치
# - 탑승객이 가장 많은 사우스샘프턴 처리

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0

# %%
## 다시 숫자로 처리
embarked_mapping = {"S": 0, "C": 1, "Q": 2}
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %% [markdown]
# ### Fare

# %% [markdown]
# #### 결측치 처리
# - class 별 평균값으로 처리

# %%
# fill missing Fare with median fare for each Pclass
train["Fare"].fillna(train["Fare"].mean(), inplace=True)
test["Fare"].fillna(test["Fare"].mean(), inplace=True)
train.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  1.0      1      0         A/5 21171
# 1             2         1       1    1  2.0      1      0          PC 17599
# 2             3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  2.0      1      0            113803
# 4             5         0       3    0  2.0      0      0            373450
# 5             6         0       3    0  1.0      0      0            330877
# 6             7         0       1    0  3.0      0      0             17463
# 7             8         0       3    0  0.0      3      1            349909
# 8             9         1       3    1  1.0      0      2            347742
# 9            10         1       2    1  0.0      1      0            237736
# 10           11         1       3    1  0.0      1      1           PP 9549
# 11           12         1       1    1  3.0      0      0            113783
# 12           13         0       3    0  1.0      0      0         A/5. 2151
# 13           14         0       3    0  2.0      1      5            347082
# 14           15         0       3    1  0.0      0      0            350406
# 15           16         1       2    1  3.0      0      0            248706
# 16           17         0       3    0  0.0      4      1            382652
# 17           18         1       2    0  1.0      0      0            244373
# 18           19         0       3    1  2.0      1      0            345763
# 19           20         1       3    1  1.0      0      0              2649
# 20           21         0       2    0  2.0      0      0            239865
# 21           22         1       2    0  2.0      0      0            248698
# 22           23         1       3    1  0.0      0      0            330923
# 23           24         1       1    0  1.0      0      0            113788
# 24           25         0       3    1  0.0      3      1            349909
# 25           26         1       3    1  2.0      1      5            347077
# 26           27         0       3    0  1.0      0      0              2631
# 27           28         0       1    0  1.0      3      2             19950
# 28           29         1       3    1  1.0      0      0            330959
# 29           30         0       3    0  1.0      0      0            349216
# 30           31         0       1    0  2.0      0      0          PC 17601
# 31           32         1       1    1  1.0      1      0          PC 17569
# 32           33         1       3    1  1.0      0      0            335677
# 33           34         0       2    0  4.0      0      0        C.A. 24579
# 34           35         0       1    0  1.0      1      0          PC 17604
# 35           36         0       1    0  3.0      1      0            113789
# 36           37         1       3    0  1.0      0      0              2677
# 37           38         0       3    0  1.0      0      0        A./5. 2152
# 38           39         0       3    1  1.0      2      0            345764
# 39           40         1       3    1  0.0      1      0              2651
# 40           41         0       3    1  2.0      1      0              7546
# 41           42         0       2    1  1.0      1      0             11668
# 42           43         0       3    0  1.0      0      0            349253
# 43           44         1       2    1  0.0      1      2     SC/Paris 2123
# 44           45         1       3    1  1.0      0      0            330958
# 45           46         0       3    0  1.0      0      0   S.C./A.4. 23567
# 46           47         0       3    0  1.0      1      0            370371
# 47           48         1       3    1  1.0      0      0             14311
# 48           49         0       3    0  1.0      2      0              2662
# 49           50         0       3    1  1.0      1      0            349237
#
#         Fare        Cabin  Embarked  Title
# 0     7.2500          NaN         0      0
# 1    71.2833          C85         1      2
# 2     7.9250          NaN         0      1
# 3    53.1000         C123         0      2
# 4     8.0500          NaN         0      0
# 5     8.4583          NaN         2      0
# 6    51.8625          E46         0      0
# 7    21.0750          NaN         0      3
# 8    11.1333          NaN         0      2
# 9    30.0708          NaN         1      2
# 10   16.7000           G6         0      1
# 11   26.5500         C103         0      1
# 12    8.0500          NaN         0      0
# 13   31.2750          NaN         0      0
# 14    7.8542          NaN         0      1
# 15   16.0000          NaN         0      2
# 16   29.1250          NaN         2      3
# 17   13.0000          NaN         0      0
# 18   18.0000          NaN         0      2
# 19    7.2250          NaN         1      2
# 20   26.0000          NaN         0      0
# 21   13.0000          D56         0      0
# 22    8.0292          NaN         2      1
# 23   35.5000           A6         0      0
# 24   21.0750          NaN         0      1
# 25   31.3875          NaN         0      2
# 26    7.2250          NaN         1      0
# 27  263.0000  C23 C25 C27         0      0
# 28    7.8792          NaN         2      1
# 29    7.8958          NaN         0      0
# 30   27.7208          NaN         1      3
# 31  146.5208          B78         1      2
# 32    7.7500          NaN         2      1
# 33   10.5000          NaN         0      0
# 34   82.1708          NaN         1      0
# 35   52.0000          NaN         0      0
# 36    7.2292          NaN         1      0
# 37    8.0500          NaN         0      0
# 38   18.0000          NaN         0      1
# 39   11.2417          NaN         1      1
# 40    9.4750          NaN         0      2
# 41   21.0000          NaN         0      2
# 42    7.8958          NaN         1      0
# 43   41.5792          NaN         1      1
# 44    7.8792          NaN         2      1
# 45    8.0500          NaN         0      0
# 46   15.5000          NaN         2      0
# 47    7.7500          NaN         2      1
# 48   21.6792          NaN         1      0
# 49   17.8000          NaN         0      2

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
 
plt.show()

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0, 20)
# Out:
# (0.0, 20.0)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0, 30)
# Out:
# (0.0, 30.0)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0.0, 512.3292)

# %%
## 요금별 bin 처리
for dataset in train_test_data:
    dataset.loc[ dataset['Fare'] <= 17, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 17) & (dataset['Fare'] <= 30), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 30) & (dataset['Fare'] <= 100), 'Fare'] = 2
    dataset.loc[ dataset['Fare'] > 100, 'Fare'] = 3

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare Cabin  Embarked  Title
# 0   0.0   NaN         0      0
# 1   2.0   C85         1      2
# 2   0.0   NaN         0      1
# 3   2.0  C123         0      2
# 4   0.0   NaN         0      0

# %% [markdown]
# ### 4.7 Cabin

# %%
train.Cabin.value_counts()
# Out:
# B96 B98        4
# C23 C25 C27    4
# G6             4
# F33            3
# E101           3
#               ..
# B19            1
# A24            1
# E63            1
# B38            1
# F38            1
# Name: Cabin, Length: 147, dtype: int64

# %%
## cabin의 앞자리  알파벳만 가져와서 처리
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].str[:1]

# %%
## class별 정리
Pclass1 = train[train['Pclass']==1]['Cabin'].value_counts()
Pclass2 = train[train['Pclass']==2]['Cabin'].value_counts()
Pclass3 = train[train['Pclass']==3]['Cabin'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
## 소수점을 통해 분류해서 머신러닝 학습에 도움을 주기 위해 (정수로 표현하면 거리감이 있어서 학습에 안좋음)
cabin_mapping = {"A": 0, "B": 0.4, "C": 0.8, "D": 1.2, "E": 1.6, "F": 2, "G": 2.4, "T": 2.8}
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].map(cabin_mapping)

# %%
# fill missing Fare with median fare for each Pclass
train["Cabin"].fillna(train["Cabin"].mean(), inplace=True)
test["Cabin"].fillna(test["Cabin"].mean(), inplace=True)

# %% [markdown]
# ### FamilySize

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'FamilySize',shade= True)
facet.set(xlim=(0, train['FamilySize'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0.0, 11.0)

# %%
family_mapping = {1: 0, 2: 0.4, 3: 0.8, 4: 1.2, 5: 1.6, 6: 2, 7: 2.4, 8: 2.8, 9: 3.2, 10: 3.6, 11: 4}
for dataset in train_test_data:
    dataset['FamilySize'] = dataset['FamilySize'].map(family_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare     Cabin  Embarked  Title  FamilySize
# 0   0.0  0.956863         0      0         0.4
# 1   2.0  0.800000         1      2         0.4
# 2   0.0  0.956863         0      1         0.0
# 3   2.0  0.800000         0      2         0.4
# 4   0.0  0.956863         0      0         0.0

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare     Cabin  Embarked  Title  FamilySize
# 0   0.0  0.956863         0      0         0.4
# 1   2.0  0.800000         1      2         0.4
# 2   0.0  0.956863         0      1         0.0
# 3   2.0  0.800000         0      2         0.4
# 4   0.0  0.956863         0      0         0.0

# %%
features_drop = ['Ticket', 'SibSp', 'Parch']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)
train = train.drop(['PassengerId'], axis=1)

# %%
train_data = train.drop('Survived', axis=1)
target = train['Survived']

train_data.shape, target.shape
# Out:
# ((891, 8), (891,))

# %%
train_data.head(10)
# Out:
#    Pclass  Sex  Age  Fare     Cabin  Embarked  Title  FamilySize
# 0       3    0  1.0   0.0  0.956863         0      0         0.4
# 1       1    1  2.0   2.0  0.800000         1      2         0.4
# 2       3    1  1.0   0.0  0.956863         0      1         0.0
# 3       1    1  2.0   2.0  0.800000         0      2         0.4
# 4       3    0  2.0   0.0  0.956863         0      0         0.0
# 5       3    0  1.0   0.0  0.956863         2      0         0.0
# 6       1    0  3.0   2.0  1.600000         0      0         0.0
# 7       3    0  0.0   1.0  0.956863         0      3         1.6
# 8       3    1  1.0   0.0  0.956863         0      2         0.8
# 9       2    1  0.0   2.0  0.956863         1      2         0.4

# %% [markdown]
# ## 5. Modelling

# %%
# Importing Classifier Modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Sex         891 non-null    int64
#  3   Age         891 non-null    float64
#  4   Fare        891 non-null    float64
#  5   Cabin       891 non-null    float64
#  6   Embarked    891 non-null    int64
#  7   Title       891 non-null    int64
#  8   FamilySize  891 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 62.8 KB

# %%
train = train.astype({'Age':'int'})

# %% [markdown]
# ### 6. Cross Validation (K-fold)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %% [markdown]
# ### 6.2.1 kNN

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
clf.fit(train_data, target)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.83333333 0.75280899 0.82022472 0.82022472 0.86516854 0.80898876
#  0.84269663 0.78651685 0.83146067 0.82022472]

# %%
# kNN Score
round(np.mean(score)*100, 2)
# Out:
# 81.82

# %% [markdown]
# ### 6.2.2 Decision Tree

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.82222222 0.85393258 0.78651685 0.7752809  0.86516854 0.82022472
#  0.82022472 0.80898876 0.70786517 0.80898876]

# %%
# decision tree Score
round(np.mean(score)*100, 2)
# Out:
# 80.69

# %% [markdown]
# ### 6.2.3 Ramdom Forest

# %%
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.82222222 0.84269663 0.78651685 0.76404494 0.85393258 0.80898876
#  0.80898876 0.76404494 0.7752809  0.78651685]

# %%
# Random Forest Score
round(np.mean(score)*100, 2)
# Out:
# 80.13

# %% [markdown]
# ### 6.2.4 Naive Bayes

# %%
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.82222222 0.73033708 0.78651685 0.76404494 0.75280899 0.78651685
#  0.82022472 0.84269663 0.82022472 0.83146067]

# %%
# Naive Bayes Score
round(np.mean(score)*100, 2)
# Out:
# 79.57

# %% [markdown]
# ### 6.2.5 SVM

# %%
clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.82222222 0.78651685 0.83146067 0.80898876 0.84269663 0.82022472
#  0.84269663 0.85393258 0.83146067 0.85393258]

# %%
round(np.mean(score)*100,2)
# Out:
# 82.94

# %% [markdown]
# ## 7. Testing

# %%
clf = SVC()
clf.fit(train_data, target)

test_data = test.drop("PassengerId", axis=1).copy()
prediction = clf.predict(test_data)
# Out:
# SVC()

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": prediction
    })

submission.to_csv('submission.csv', index=False)

# %%
submission = pd.read_csv('submission.csv')
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %% [markdown]
# ## References
#
# This notebook is created by learning from the following notebooks:
#
# - [Mukesh ChapagainTitanic Solution: A Beginner's Guide](https://www.kaggle.com/chapagain/titanic-solution-a-beginner-s-guide?scriptVersionId=1473689)
# - [How to score 0.8134 in Titanic Kaggle Challenge](http://ahmedbesbes.com/how-to-score-08134-in-titanic-kaggle-challenge.html)
# - [Titanic: factors to survive](https://olegleyz.github.io/titanic_factors.html)
# - [Titanic Survivors Dataset and Data Wrangling](http://www.codeastar.com/data-wrangling/)
